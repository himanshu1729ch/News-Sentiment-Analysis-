# %% [markdown]
#  ## Sentiment Analysis of daily NEWS

# %% [markdown]
# #### Description:
#
# This projects attempts to analyze the daily news we are subjected to. The complete analysis consists of 2 Sections.
#
# <font color='red'>Section 1:</font> This section involves sentiment analysis of the news articles, We try and investigate if the sentiments associated with the news articles to answer the following questions
# 1. Is the Media focussing too much on the negative side of the story? Do the negative news dominate the headlines ?
# 2. Is there a perticular trend in the way the major publishishers from around the world report stories?
# 3. Do the word distribution in news articles picked up randomly follow the zipf's law?
# 4. Bigram Analysis of the headlines
#
# <font color='red'>Section 2:</font> Impact of News sentiment on stock market prices. Does it mean that if news is demoninated with negative news, the stock prices fall?

# %% [markdown]
# Note: While rerunning the data collection part, kindly ensure that the start date of the API call is no later than one month prior to the current date in order to avoid any errors

# %%
import requests
import json
import numpy as np
import pandas as pd
import nltk 
import matplotlib
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from string import punctuation
import re
import numpy as np
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from rake_nltk import Rake

# %%
#pip install rake-nltk

# %%
#pip install requests

# %% [markdown]
# ### Task 1: Identify a suitable web API
#
# <font color='red'>API Chosen:</font> Two API's were chosen for this project, all the news articles were collected from https://newsapi.org/ . NewsAPI provides real time news articles from a wide variety of news publishers. The data for the stock prices was needed in the Section 2 of this project and hence another API was needed. The data was obtained from https://www.worldtradingdata.com/

# %%
url = 'https://newsapi.org/v2/everything?'

# %%
api_key = '50fef5371a044f678bf494650b977047'

# %% [markdown]
# The following two functions are used to gather the data from the api and put it in a dataframe. The get_article function
# takes the raw data in the form of a dictionary and combines it in a structured format

# %%
# function to take raw data from the API and process it into a list inorder to trnasform it into a pandas dataframe
def get_articles(file): 
    article_results = [] 
    for i in range(len(file)):
        article_dict = {}
        article_dict['title'] = file[i]['title']
        article_dict['author'] = file[i]['author']
        article_dict['source'] = file[i]['source']
        article_dict['description'] = file[i]['description']
        article_dict['content'] = file[i]['content']
        article_dict['pub_date'] = file[i]['publishedAt']
        article_dict['url'] = file[i]["url"]
        article_dict['photo_url'] = file[i]['urlToImage']
        article_results.append(article_dict)
    return article_results

# %% [markdown]
# ### Task 2: Collect data your chosen API(s)
# The data for this assignment was collected in two stages. Since the API had a restrictions. The API only returned 100 news articles in API call and the news could only be collected upto 1 month prior to the current date. In order to collect sufficent data for analysis, I used to approaches:
#
# 1. Collect 100 articles per New Publishso that I could iterate through alist of News publishers and collect 100 news articles from each one of them
# 2. Collect data in two phases. In phase 1 of the collection i collected data from 14th February till 14th March and in phase 2 I collected data from 15th March onwards till 29th of March 2020.

# %%
# Collecting the first 100 articles about Facebook to check the API and the working of the function 
parameters_headlines = {
    'q': 'Facebook is down',
    'sortBy':'popularity',
    'pageSize': 100,
    'apiKey': api_key,
    'language': 'en',
    'from' : '2021-09-19'    
}
# making the API call 
response_headline = requests.get(url, params = parameters_headlines)
response_json_headline = response_headline.json()
print(response_json_headline)
# Out:
# {'status': 'ok', 'totalResults': 13615, 'articles': [{'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Kris Holt', 'title': 'Snapchat is down', 'description': "Some Snapchat users are having problems with the app this morning, with several noting on Twitter that they're unable to send snaps. The company acknowledged the outage and said it was looking into the matter.\xa0We’re aware that some Snapchatters are having iss…", 'url': 'https://www.engadget.com/snapchat-down-error-outage-snaps-142107269.html', 'urlToImage': 'https://s.yimg.com/os/creatr-images/2019-06/1be1c810-982e-11e9-bdd0-b68b2199f048', 'publishedAt': '2021-10-13T14:21:07Z', 'content': "Some Snapchat users are having problems with the app this morning, with several noting on Twitter that they're unable to send snaps. The company acknowledged the outage and said it was looking into t… [+1052 chars]"}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Igor Bonifacic', 'title': 'Facebook is down, along with Instagram, WhatsApp and Messenger', 'description': "If you can't access Facebook, Instagram, Messenger or WhatsApp, you're not the only one. Starting at approximately 11:38AM ET, Downdetector began logging a spike in outage reports across all four Facebook-owned services. Andy Stone, a spokesperson for the com…", 'url': 'https://www.engadget.com/facebook-instagram-whatsapp-messenger-down-161653706.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-10/a3928f90-252d-11ec-9eb7-d7e722c7c04e', 'publishedAt': '2021-10-04T16:16:53Z', 'content': "If you can't access Facebook, Instagram, Messenger or WhatsApp, you're not the only one. Starting at approximately 11:38AM ET, Downdetector began logging a spike in outage reports across all four Fac… [+508 chars]"}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Jon Fingas', 'title': "Facebook's chief technology officer is leaving the company after 13 years", 'description': "Facebook is about to close an important chapter in its history. CNBCreports the social network's chief technology officer, Mike Schroepfer, is stepping down from his role after a total 13 years at the company. He'll move to a part-time position as Facebook's …", 'url': 'https://www.engadget.com/facebook-cto-steps-down-2022-205051710.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-09/d1c03c60-1be5-11ec-b1b5-2c26965a1640', 'publishedAt': '2021-09-22T20:50:51Z', 'content': "Facebook is about to close an important chapter in its history. CNBCreports the social network's chief technology officer, Mike Schroepfer, is stepping down from his role after a total 13 years at th… [+229 chars]"}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Igor Bonifacic', 'title': 'Facebook explains how its October 4th outage started', 'description': "Following Monday’s massive service outage that took out all of its services, Facebook has published a blog post detailing what happened yesterday. According to Santosh Janardhan, the company's vice president of infrastructure, the outage started with what sho…", 'url': 'https://www.engadget.com/facebook-outage-explainer-193155776.html', 'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-10/edc78c20-2611-11ec-bde6-5fb47d3ad17d', 'publishedAt': '2021-10-05T19:31:55Z', 'content': "Following Mondays massive service outage that took out all of its services, Facebook has published a blog post detailing what happened yesterday. According to Santosh Janardhan, the company's vice pr… [+2180 chars]"}, {'source': {'id': 'engadget', 'name': 'Engadget'}, 'author': 'Kris Holt', 'title': 'Facebook will open up the Oculus Go to tinkerers with an unlocked OS', 'description': 'Facebook\r\n will soon let folks who still have an Oculus Go\r\n do so much more with the virtual reality headset. The company will release an unlocked build of the operating system, which users can sideload to get full root access and do just about anything they…', 'url ...

# %%
responses = response_json_headline["articles"]
# transforminf the data from JSON dictionary to a pandas data frame
news_articles_df = pd.DataFrame(get_articles(responses))
# printing the head to check the format and the working of the get_articles function
news_articles_df.head()
# Out:
#            author                                            content  \
# 0       Kris Holt  Some Snapchat users are having problems with t...
# 1  Igor Bonifacic  If you can't access Facebook, Instagram, Messe...
# 2      Jon Fingas  Facebook is about to close an important chapte...
# 3  Igor Bonifacic  Following Mondays massive service outage that ...
# 4       Kris Holt  Facebook\r\n will soon let folks who still hav...
#
#                                          description  \
# 0  Some Snapchat users are having problems with t...
# 1  If you can't access Facebook, Instagram, Messe...
# 2  Facebook is about to close an important chapte...
# 3  Following Monday’s massive service outage that...
# 4  Facebook\r\n will soon let folks who still hav...
#
#                                            photo_url              pub_date  \
# 0  https://s.yimg.com/os/creatr-images/2019-06/1b...  2021-10-13T14:21:07Z
# 1  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04T16:16:53Z
# 2  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-22T20:50:51Z
# 3  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-05T19:31:55Z
# 4  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-27T15:10:00Z
#
#                                    source  \
# 0  {'id': 'engadget', 'name': 'Engadget'}
# 1  {'id': 'engadget', 'name': 'Engadget'}
# 2  {'id': 'engadget', 'name': 'Engadget'}
# 3  {'id': 'engadget', 'name': 'Engadget'}
# 4  {'id': 'engadget', 'name': 'Engadget'}
#
#                                                title  \
# 0                                   Snapchat is down
# 1  Facebook is down, along with Instagram, WhatsA...
# 2  Facebook's chief technology officer is leaving...
# 3  Facebook explains how its October 4th outage s...
# 4  Facebook will open up the Oculus Go to tinkere...
#
#                                                  url
# 0  https://www.engadget.com/snapchat-down-error-o...
# 1  https://www.engadget.com/facebook-instagram-wh...
# 2  https://www.engadget.com/facebook-cto-steps-do...
# 3  https://www.engadget.com/facebook-outage-expla...
# 4  https://www.engadget.com/facebook-oculus-go-op...

# %% [markdown]
# As we can see from the above result that the data is correctly being transformed from a dictionary to a pandas dataframe and hence we can go ahead and loop through the list of reputated sources and make an API call to fetch 100 news articles from that source. I appended the results of each API call to the dataframe. This alowed me to collect collect sufficient data from the API

# %%
responses = list() # stores responses for various news sources
domains = ['news.yahoo.com','wsj.com','aljazeera.com','bbc.co.uk','techcrunch.com', 'nytimes.com','bloomberg.com','businessinsider.com',
             'cbc.ca','cnbc.com','cnn.com','ew.com','espn.go.com','espncricinfo.com','foxnews.com', 'apnews.com',
             'news.nationalgeographic.com','nymag.com','reuters.com','rte.ie','thehindu.com','huffingtonpost.com',
             'irishtimes.com','timesofindia.indiatimes.com','washingtonpost.com','time.com','medicalnewstoday.com',
             'ndtv.com','theguardian.com','dailymail.co.uk','firstpost.com','thejournal.ie', 'hindustantimes.com',
             'economist.com','news.vice.com','usatoday.com','telegraph.co.uk','metro.co.uk','mirror.co.uk','news.google.com']
for domain in domains:
    parameters_headlines = {
    'domains':format(domain),
    'sortBy':'popularity',
    'pageSize': 100,
    'apiKey': api_key,
    'language': 'en',
    'from' : '2021-09-19'    
    }
    rr = requests.get(url, params = parameters_headlines)
    data = rr.json()
print(data)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
responses = data["articles"]
news_articles_df=news_articles_df.append(pd.DataFrame(get_articles(responses)))
print(news_articles_df.shape)
news_articles_df
# Out:
# (100, 8)
#                                               author  \
# 0                                          Kris Holt
# 1                                     Igor Bonifacic
# 2                                         Jon Fingas
# 3                                     Igor Bonifacic
# 4                                          Kris Holt
# 5                                          Mat Smith
# 6                                      Mariella Moon
# 7                                          Mat Smith
# 8                                     Arielle Pardes
# 9                                  Noah Giansiracusa
# 10                                  Chisom Peter Job
# 11                                   Eleanor Cummins
# 12                                         Mar Hicks
# 13                               Ian Carlos Campbell
# 14                                    Richard Lawler
# 15                                        Alex Heath
# 16                                        Jon Porter
# 17                           Jennifer Pattison Tuohy
# 18                                        Alex Cranz
# 19                                     James Vincent
# 20                                        Jay Peters
# 21                                    Nicole Wetsman
# 22                                        Jon Porter
# 23                                     Adi Robertson
# 24                                       Nilay Patel
# 25                     noreply@blogger.com (Unknown)
# 26                     noreply@blogger.com (Unknown)
# 27                     noreply@blogger.com (Unknown)
# 28                                      Brian Heater
# 29                     noreply@blogger.com (Unknown)
# ..                                               ...
# 70     Ryan Young, Jason Morris and Ray Sanchez, CNN
# 71                  https://www.facebook.com/bbcnews
# 72                  https://www.facebook.com/bbcnews
# 73                  https://www.facebook.com/bbcnews
# 74                  https://www.facebook.com/bbcnews
# 75                  https://www.facebook.com/bbcnews
# 76                  https://www.facebook.com/bbcnews
# 77                  https://www.facebook.com/bbcnews
# 78                                        Jim Salter
# 79                                      Tim De Chant
# 80                                      Tim De Chant
# 81           Chanelle GarciaGoogle Web Creators team
# 82           Chanelle GarciaGoogle Web Creators team
# 83                                       Stadia Team
# 84                                 Reuters Editorial
# 85                                              None
# 86                                       Sheila Dang
# 87                                              None
# 88  Nafisa Eltahir, Malaika Tapper, Khalid Abdelaziz
# 89                                              None
# 90                                              None
# 91                                     Reuters Staff
# 92                                              None
# 93                                              None
# 94                                              None
# 95                                              None
# 96                                              None
# 97                                              None
# 98                                       Sheila Dang
# 99                                              None
#
#                                               content  \
# 0   Some Snapchat users are having problems with t...
# 1   If you can't access Facebook, Instagram, Messe...
# 2   Facebook is about to close an important chapte...
# 3   Following Mondays massive service outage that ...
# 4   Facebook\r\n will soon let folks who still hav...
# 5   Welcome to Monday. How was your weekend? For m...
# 6   2Africa, a subsea cable project funded by Face...
# 7   Well get into why Facebook saw its entire busi...
# 8   The return of tech conferences began not with ...
# 9   In public, Facebook seems to claim that it rem...
# 10  Tomiwa Ibukunle, a 21-year-old entrepreneur in...
# 11  A trove of leaked documents and a recent congr...
# 12  But the idea that Facebooks technological unde...
# 13  Filed under:\r\nKicking another social network...
# 14  Its probably DNS\r\nIllustration by Alex Castr...
# 15  Engineers have been sent to a California data ...
# 16  Giving users full root access\r\nThe Oculus Go...
# 17  If you buy something from a Verge link, Vox Me...
# 18  The claims are in response to a damning Wall S...
# 19  The browser extension essentially wiped users ...
# 20  Tough week for Facebook\r\nIllustration by Ale...
# 21  Efforts to minimize the findings arent good fo...
# 22  Encrypted messaging app Signal also reports ga...
# 23  HTC wants to find a new VR market — but what i...
# 24  Photo Illustration by Grayson Blackmon / The V...
# 25  Users also reported issues with Facebook’s onl...
# 26  Facebook is continuing to have one of its long...
# 27  If Mark Zuckerberg’s “juvenile jottings” on pr...
# 28  The Portal line has always been a kind of odd ...
# 29  A US judge has ordered Facebook to release rec...
# ..                                                ...
# 70  (CNN)Jessica Desfosses shared the final heartr...
# 71  Image source, Getty Images\r\nImage caption, F...
# 72  By Mark SavageBBC Music Correspondent\r\nimage...
# 73  By Niall GlynnBBC News NI \r\nImage source, Ri...
# 74  Image source, Getty Images\r\nImage caption, D...
# 75  Image source, Ashley Cooper GWI\r\nImage capti...
# 76  By Annabel RackhamNewsbeat reporter\r\n"Everyo...
# 77  By BBC MonitoringEssential Media Insight\r\nim...
# 78  Enlarge/ Today's global Facebook and Facebook-...
# 79  Enlarge/ Former Facebook employee Frances Haug...
# 80  Enlarge/ Facebook CEO Mark Zuckerberg testifyi...
# 81  She founded Andi Eaton Creatives, a team of di...
# 82  Eden Hagos grew up in Windsor, Ontario, Canada...
# 83  In September, the Stadia Pro library grew to m...
# 84  Posted \r\nThe $920 bln social network is figh...
# 85  Facebook logo is displayed through broken glas...
# 86  (Reuters) - Facebook Inc said on Wednesday it ...
# 87  Sept 22 (Reuters) - Facebook Inc (FB.O) said o...
# 88  CAIRO/KHARTOUM (Reuters) - Facebook says it ha...
# 89  CAIRO/KHARTOUM, Oct 19 (Reuters) - Facebook sa...
# 90  A Facebook logo is displayed on a smartphone i...
# 91  By Reuters Staff\r\nA look at the day ahead fr...
# 92  BRUSSELS/STOCKHOLM, Oct 4 (Reuters) - Two memb...
# 93  WASHINGTON, Oct 5 (Reuters Breakingviews) - A ...
# 94  People wearing face masks walk by the New York...
# 95  The Facebook logo is displayed on a mobile pho...
# 96  Oct 4 (Reuters) - Facebook, Instagram and What...
# 97  The Facebook logo is displayed on a mobile pho...
# 98  FILE PHOTO: Attendees walk past a Facebook log...
# 99  A 3D-printed Facebook logo is seen placed on a...
#
#                                           description  \
# 0   Some Snapchat users are having problems with t...
# 1   If you can't access Facebook, Instagram, Messe...
# 2   Facebook is about to close an important chapte...
# 3   Following Monday’s massive service outage that...
# 4   Facebook\r\n will soon let folks who still hav...
# 5   Welcome to Monday. How was your weekend? For m...
# 6   2Africa, a subsea cable project funded by Face...
# 7   We’ll get into why Facebook saw its entire bus...
# 8   Hundreds of (vaccinated) attendees gathered in...
# 9   The company publicly claims its AI is amazing ...
# 10  The platform's shutdown sparked uncertainty an...
# 11  It's almost inevitable that social media force...
# 12  Before there was Big Tech, there were auto com...
# 13  Twitter CEO Jack Dorsey is dunking on Facebook...
# 14  Facebook, Instagram, WhatsApp, and Messenger a...
# 15  Engineers have been sent to a California data ...
# 16  Facebook is unlocking the software and bootloa...
# 17  The Portal Go from Facebook is excellent as a ...
# 18  Ahead of a Senate committee hearing Facebook’s...
# 19  Louis Barclay, the developer behind the Unfoll...
# 20  Facebook said that some of its services are ex...
# 21  Internal research at Facebook showing that Ins...
# 22  Messaging app Telegram gained a record 70 mill...
# 23  HTC has announced the Vive Flow, a $499 virtua...
# 24  Jeep CEO Christian Meunier talks about the new...
# 25  Social media platforms Facebook, Instagram and...
# 26  Facebook is continuing to have one of its long...
# 27  If Mark Zuckerberg’s “juvenile jottings” on pr...
# 28  The Portal line has always been a kind of odd ...
# 29  A US judge has ordered Facebook to release rec...
# ..                                                ...
# 70  The coronavirus has become the leading cause o...
# 71  A former employee tells the US Senate that the...
# 72  The pop star is joining Abba's live band next ...
# 73  Thousands of small spiders have been spotted o...
# 74  Why the need to be a people's representative a...
# 75  The half-eaten food and glasses of fizz were f...
# 76  Call Her Daddy host Alex Cooper has re-launche...
# 77  Newspapers across Europe are watching the knif...
# 78  The root cause of the worldwide outage appears...
# 79  Section 230 reform is just a start, Frances Ha...
# 80  Executive concerns of “over-enforcement” let h...
# 81  Every morning at 7 a.m, you’ll find Andi Eaton...
# 82  Eden Hagos grew up in Windsor, Ontario, Canada...
# 83  It’s time for another update to our Stadia Sav...
# 84  The $920 bln social network is fighting on mul...
# 85  Mark Zuckerberg can’t catch a break lately. Th...
# 86  Facebook Inc said on Wednesday it is underrepo...
# 87  Facebook Inc <a href="https://www.reuters.com/...
# 88  Facebook says it has shut down two large netwo...
# 89  Facebook says it has shut down two large netwo...
# 90  A U.S federal judge has ordered Facebook <a hr...
# 91  U.S. and European bond yields are up sharply, ...
# 92  Two members of the European parliament have ca...
# 93  A whistleblower’s claim that Facebook <a href=...
# 94  U.S. stocks fell on Monday, with the Nasdaq do...
# 95  A Moscow court told state bailiffs on Thursday...
# 96  Facebook, Instagram and WhatsApp at least part...
# 97  Former Facebook <a href="https://www.reuters.c...
# 98  Facebook Inc on Thursday said it reduces the d...
# 99  Facebook <a href="https://www.reuters.com/comp...
#
#                                             photo_url              pub_date  \
# 0   https://s.yimg.com/os/creatr-images/2019-06/1b...  2021-10-13T14:21:07Z
# 1   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04T16:16:53Z
# 2   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-22T20:50:51Z
# 3   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-05T19:31:55Z
# 4   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-27T15:10:00Z
# 5   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04T11:15:46Z
# 6   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-28T07:00:58Z
# 7   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-06T11:15:08Z
# 8   https://media.wired.com/photos/615607db296d418...  2021-10-01T18:22:54Z
# 9   https://media.wired.com/photos/6168c9b0c12c627...  2021-10-15T11:00:00Z
# 10  https://media.wired.com/photos/61644befd5b17ce...  2021-10-11T16:40:05Z
# 11  https://media.wired.com/photos/6160e0d27d0472a...  2021-10-10T13:00:00Z
# 12  https://media.wired.com/photos/6164e61a15502b8...  2021-10-14T13:00:00Z
# 13  https://cdn.vox-cdn.com/thumbor/dn50zT86uS4Kmr...  2021-10-04T18:47:54Z
# 14  https://cdn.vox-cdn.com/thumbor/BX718uWWEZPX7s...  2021-10-04T16:01:29Z
# 15  https://cdn.vox-cdn.com/thumbor/KqmvMUzxiqwsVn...  2021-10-04T21:13:18Z
# 16  https://cdn.vox-cdn.com/thumbor/jwK3_Qmzq-mUHx...  2021-09-27T13:28:44Z
# 17  https://cdn.vox-cdn.com/thumbor/IbbRKQHBHSEIJv...  2021-10-19T14:00:00Z
# 18  https://cdn.vox-cdn.com/thumbor/AhEDh8cXLzPzD8...  2021-09-27T02:38:02Z
# 19  https://cdn.vox-cdn.com/thumbor/BX718uWWEZPX7s...  2021-10-08T10:24:27Z
# 20  https://cdn.vox-cdn.com/thumbor/GD8_ddV1_zZQH7...  2021-10-08T19:28:43Z
# 21  https://cdn.vox-cdn.com/thumbor/AhEDh8cXLzPzD8...  2021-10-06T17:28:41Z
# 22  https://cdn.vox-cdn.com/thumbor/ma3VFJyH8a5RbM...  2021-10-06T08:39:20Z
# 23  https://cdn.vox-cdn.com/thumbor/WdAguvf8zZvG0m...  2021-10-14T15:01:10Z
# 24  https://cdn.vox-cdn.com/thumbor/W_OuY_Xlg2l3_I...  2021-10-19T13:44:15Z
# 25  https://blogger.googleusercontent.com/img/a/AV...  2021-10-04T20:28:00Z
# 26  https://lh6.googleusercontent.com/proxy/qBgVib...  2021-10-04T20:40:00Z
# 27  https://blogger.googleusercontent.com/img/a/AV...  2021-10-08T16:37:00Z
# 28  https://techcrunch.com/wp-content/uploads/2021...  2021-09-21T17:00:25Z
# 29                                               None  2021-09-23T18:14:00Z
# ..                                                ...                   ...
# 70  https://cdn.cnn.com/cnnnext/dam/assets/2110160...  2021-10-16T19:38:25Z
# 71  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-05T18:10:55Z
# 72  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-24T00:40:28Z
# 73  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-18T06:44:49Z
# 74  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-16T10:39:48Z
# 75  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-14T11:42:31Z
# 76  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-11T23:44:36Z
# 77  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-27T11:40:56Z
# 78  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-04T17:26:55Z
# 79  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-06T15:39:28Z
# 80  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-18T13:30:59Z
# 81  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-04T16:00:00Z
# 82  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-18T16:00:00Z
# 83  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-04T16:00:00Z
# 84  https://static.reuters.com/resources/r/?d=2021...  2021-10-05T18:57:40Z
# 85  https://www.reuters.com/resizer/iWX9CBkWKcK456...  2021-10-05T00:36:00Z
# 86  https://static.reuters.com/resources/r/?m=02&d...  2021-09-22T15:11:00Z
# 87  https://www.reuters.com/resizer/SWy6K01fXaw0nI...  2021-09-22T15:17:00Z
# 88  https://static.reuters.com/resources/r/?m=02&d...  2021-10-19T12:10:00Z
# 89  https://www.reuters.com/resizer/2ODf5QEC2mrOhl...  2021-10-19T12:28:00Z
# 90  https://www.reuters.com/resizer/3m7-iscj1GlyJh...  2021-09-23T04:15:00Z
# 91  https://static.reuters.com/resources/r/?m=02&d...  2021-10-06T07:01:00Z
# 92  https://www.reuters.com/resizer/qbGoR5eW6dNaHv...  2021-10-04T13:59:00Z
# 93  https://www.reuters.com/resizer/FUBQgSaLeBr6ya...  2021-10-05T14:52:00Z
# 94  https://www.reuters.com/resizer/LuYrRuaMXfE38x...  2021-09-20T19:12:00Z
# 95  https://www.reuters.com/resizer/bkpMrSE3Eq5SUn...  2021-10-07T14:31:00Z
# 96  https://www.reuters.com/resizer/s2JlzcF-tZygn0...  2021-10-04T23:00:00Z
# 97  https://www.reuters.com/resizer/kc9JHdjbP5S5fd...  2021-10-04T19:54:00Z
# 98  https://static.reuters.com/resources/r/?m=02&d...  2021-09-23T09:10:00Z
# 99  https://www.reuters.com/resizer/c50YMM49bOgIEC...  2021-10-05T07:40:00Z
#
#                                             source  \
# 0           {'id': 'engadget', 'name': 'Engadget'}
# 1           {'id': 'engadget', 'name': 'Engadget'}
# 2           {'id': 'engadget', 'name': 'Engadget'}
# 3           {'id': 'engadget', 'name': 'Engadget'}
# 4           {'id': 'engadget', 'name': 'Engadget'}
# 5           {'id': 'engadget', 'name': 'Engadget'}
# 6           {'id': 'engadget', 'name': 'Engadget'}
# 7           {'id': 'engadget', 'name': 'Engadget'}
# 8                 {'id': 'wired', 'name': 'Wired'}
# 9                 {'id': 'wired', 'name': 'Wired'}
# 10                {'id': 'wired', 'name': 'Wired'}
# 11                {'id': 'wired', 'name': 'Wired'}
# 12                {'id': 'wired', 'name': 'Wired'}
# 13        {'id': 'the-verge', 'name': 'The Verge'}
# 14        {'id': 'the-verge', 'name': 'The Verge'}
# 15        {'id': 'the-verge', 'name': 'The Verge'}
# 16        {'id': 'the-verge', 'name': 'The Verge'}
# 17        {'id': 'the-verge', 'name': 'The Verge'}
# 18        {'id': 'the-verge', 'name': 'The Verge'}
# 19        {'id': 'the-verge', 'name': 'The Verge'}
# 20        {'id': 'the-verge', 'name': 'The Verge'}
# 21        {'id': 'the-verge', 'name': 'The Verge'}
# 22        {'id': 'the-verge', 'name': 'The Verge'}
# 23        {'id': 'the-verge', 'name': 'The Verge'}
# 24        {'id': 'the-verge', 'name': 'The Verge'}
# 25            {'id': None, 'name': 'Blogspot.com'}
# 26            {'id': None, 'name': 'Blogspot.com'}
# 27            {'id': None, 'name': 'Blogspot.com'}
# 28      {'id': 'techcrunch', 'name': 'TechCrunch'}
# 29            {'id': None, 'name': 'Blogspot.com'}
# ..                                             ...
# 70                    {'id': 'cnn', 'name': 'CNN'}
# 71          {'id': 'bbc-news', 'name': 'BBC News'}
# 72          {'id': 'bbc-news', 'name': 'BBC News'}
# 73          {'id': 'bbc-news', 'name': 'BBC News'}
# 74          {'id': 'bbc-news', 'name': 'BBC News'}
# 75          {'id': 'bbc-news', 'name': 'BBC News'}
# 76          {'id': 'bbc-news', 'name': 'BBC News'}
# 77          {'id': 'bbc-news', 'name': 'BBC News'}
# 78  {'id': 'ars-technica', 'name': 'Ars Technica'}
# 79  {'id': 'ars-technica', 'name': 'Ars Technica'}
# 80  {'id': 'ars-technica', 'name': 'Ars Technica'}
# 81             {'id': None, 'name': 'Blog.google'}
# 82             {'id': None, 'name': 'Blog.google'}
# 83             {'id': None, 'name': 'Blog.google'}
# 84            {'id': 'reuters', 'name': 'Reuters'}
# 85            {'id': 'reuters', 'name': 'Reuters'}
# 86            {'id': 'reuters', 'name': 'Reuters'}
# 87            {'id': 'reuters', 'name': 'Reuters'}
# 88            {'id': 'reuters', 'name': 'Reuters'}
# 89            {'id': 'reuters', 'name': 'Reuters'}
# 90            {'id': 'reuters', 'name': 'Reuters'}
# 91            {'id': 'reuters', 'name': 'Reuters'}
# 92            {'id': 'reuters', 'name': 'Reuters'}
# 93            {'id': 'reuters', 'name': 'Reuters'}
# 94            {'id': 'reuters', 'name': 'Reuters'}
# 95            {'id': 'reuters', 'name': 'Reuters'}
# 96            {'id': 'reuters', 'name': 'Reuters'}
# 97            {'id': 'reuters', 'name': 'Reuters'}
# 98            {'id': 'reuters', 'name': 'Reuters'}
# 99            {'id': 'reuters', 'name': 'Reuters'}
#
#                                                 title  \
# 0                                    Snapchat is down
# 1   Facebook is down, along with Instagram, WhatsA...
# 2   Facebook's chief technology officer is leaving...
# 3   Facebook explains how its October 4th outage s...
# 4   Facebook will open up the Oculus Go to tinkere...
# 5   The Morning After: What is it with Netflix cro...
# 6   Facebook's 2Africa to become the longest subse...
# 7   The Morning After: Facebook's October 4th outa...
# 8   With Fist Bumps and Nasal Swabs, Tech Conferen...
# 9   How Facebook Hides How Terrible It Is With Hat...
# 10  In Nigeria, Facebook's Outage Revealed a Dange...
# 11             Bodies Are Canceled. Thanks, Instagram
# 12  Facebook's Fall From Grace Looks a Lot Like Fo...
# 13  Twitter is up, Facebook is down, and Jack Dors...
# 14  Facebook is down, along with Instagram, WhatsA...
# 15  Locked out and totally down: Facebook is scram...
# 16  The Oculus Go’s operating system is being unlo...
# 17  Facebook’s new Portal Go is great for video ca...
# 18  Facebook says Instagram is not ‘toxic for teen...
# 19  Facebook bans developer behind Unfollow Everyt...
# 20  Facebook confirms that some of its services ar...
# 21  Facebook’s whistleblower report confirms what ...
# 22  Telegram gains 70M new users in just one day a...
# 23  The $499 HTC Vive Flow is VR for people who do...
# 24  How Jeep is going electric, with CEO Christian...
# 25  Facebook Instagram And Whatsapp Hit by Global ...
# 26  Here's What We Know About The Facebook Outage ...
# 27  Zuckerberg’s Early Notes on Privacy Now Haunt ...
# 28  Facebook adds a battery-powered smart screen t...
# 29  US judge orders Facebook to release anti-Rohin...
# ..                                                ...
# 70  Five times as many police officers have died f...
# 71  Facebook harms children and weakens democracy:...
# 72  Little Boots says Abba's new live band is 'bad...
# 73           Invasion of the ballooning money spiders
# 74  Sir David Amess killing: Security for politici...
# 75  Lake District mysterious abandoned tea-for-two...
# 76  Call Her Daddy's Alex Cooper: 'Not everyone ca...
# 77     Papers gripped by Germany's era of uncertainty
# 78  Facebook, Instagram, WhatsApp, and Oculus are ...
# 79  Algorithms shouldn’t be protected by Section 2...
# 80  Facebook AI moderator confused videos of mass ...
# 81                 Finding a niche in holistic living
# 82  Building community and bridges through Black f...
# 83                Stadia Savepoint: September updates
# 84               BVTV: Facebook under siege - Reuters
# 85  Facebook outage is dry run for worse web crash...
# 86  Facebook warns it is 'underreporting' iOS ad r...
# 87  Facebook warns it is 'underreporting' iOS ad r...
# 88  Facebook shuts fake accounts in Sudan, as figh...
# 89  Facebook shuts fake accounts in Sudan, as figh...
# 90  U.S. court compels Facebook to release records...
# 91  Marketmind: Hunker down, it's going to be one ...
# 92  European politicians call for Facebook investi...
# 93  Best tool to rein in Big Tech is a cap on user...
# 94  S&P 500 down more than 2% as growth worries ri...
# 95  Russian court tells bailiffs to enforce collec...
# 96  Facebook, Instagram, WhatsApp partly reconnect...
# 97  Facebook 'accountable to no one,' whistleblowe...
# 98  Facebook explains content it demotes in news f...
# 99  Facebook deletes some content banned in Russia...
#
#                                                   url
# 0   https://www.engadget.com/snapchat-down-error-o...
# 1   https://www.engadget.com/facebook-instagram-wh...
# 2   https://www.engadget.com/facebook-cto-steps-do...
# 3   https://www.engadget.com/facebook-outage-expla...
# 4   https://www.engadget.com/facebook-oculus-go-op...
# 5   https://www.engadget.com/the-morning-after-wha...
# 6   https://www.engadget.com/facebook-2-africa-lon...
# 7   https://www.engadget.com/the-morning-after-fac...
# 8   https://www.wired.com/story/fist-bumps-nasal-s...
# 9   https://www.wired.com/story/facebooks-deceptiv...
# 10  https://www.wired.com/story/nigeria-whatsapp-f...
# 11  https://www.wired.com/story/instagram-mental-h...
# 12  https://www.wired.com/story/facebook-ford-fall...
# 13  https://www.theverge.com/tldr/2021/10/4/227092...
# 14  https://www.theverge.com/2021/10/4/22708989/in...
# 15  https://www.theverge.com/2021/10/4/22709575/fa...
# 16  https://www.theverge.com/2021/9/27/22696030/oc...
# 17  https://www.theverge.com/22732472/facebook-por...
# 18  https://www.theverge.com/2021/9/26/22695629/fa...
# 19  https://www.theverge.com/2021/10/8/22716044/fa...
# 20  https://www.theverge.com/2021/10/8/22716860/fa...
# 21  https://www.theverge.com/2021/10/6/22712927/fa...
# 22  https://www.theverge.com/2021/10/6/22712191/te...
# 23  https://www.theverge.com/2021/10/14/22713276/h...
# 24  https://www.theverge.com/22733877/jeep-ceo-dec...
# 25  https://techncruncher.blogspot.com/2021/10/fac...
# 26  https://techncruncher.blogspot.com/2021/10/her...
# 27  https://techncruncher.blogspot.com/2021/10/zuc...
# 28  http://techcrunch.com/2021/09/21/facebook-adds...
# 29  https://techncruncher.blogspot.com/2021/09/us-...
# ..                                                ...
# 70  https://www.cnn.com/2021/10/16/us/police-vacci...
# 71  https://www.bbc.co.uk/news/world-us-canada-588...
# 72  https://www.bbc.co.uk/news/entertainment-arts-...
# 73  https://www.bbc.co.uk/news/uk-northern-ireland...
# 74          https://www.bbc.co.uk/news/world-58937581
# 75  https://www.bbc.co.uk/news/uk-england-cumbria-...
# 76       https://www.bbc.co.uk/news/newsbeat-58719364
# 77   https://www.bbc.co.uk/news/world-europe-58706549
# 78  https://arstechnica.com/information-technology...
# 79  https://arstechnica.com/tech-policy/2021/10/al...
# 80  https://arstechnica.com/tech-policy/2021/10/fa...
# 81  https://blog.google/web-creators/finding-niche...
# 82  https://blog.google/web-creators/building-comm...
# 83  https://blog.google/products/stadia/savepoint-...
# 84    https://www.reuters.com/video/watch/idRCV00AANP
# 85  https://www.reuters.com/breakingviews/facebook...
# 86  https://www.reuters.com/article/facebook-adver...
# 87  https://www.reuters.com/technology/facebook-wa...
# 88  https://www.reuters.com/article/us-sudan-faceb...
# 89  https://www.reuters.com/world/africa/facebook-...
# 90  https://www.reuters.com/business/media-telecom...
# 91  https://www.reuters.com/article/markets-europe...
# 92  https://www.reuters.com/technology/european-po...
# 93  https://www.reuters.com/breakingviews/best-too...
# 94  https://www.reuters.com/business/sp-500-down-m...
# 95  https://www.reuters.com/technology/russian-cou...
# 96  https://www.reuters.com/technology/facebook-in...
# 97  https://www.reuters.com/technology/facebook-ac...
# 98  https://www.reuters.com/article/facebook-moder...
# 99  https://www.reuters.com/technology/facebook-de...
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Task 3: Cleaning and preprocessing the Data

# %%
# function to exatract just the name of the source of the news article and exclude other details
def source_getter(df):
    source = []
    for source_dict in df['source']:
        source.append(source_dict['name'])
    df['source'] = source #append the source to the df

# %%
# this fuincton extracts the source name from the source dictionary as seen above
source_getter(news_articles_df)

# %%
# converted the publication date to date time format for future analysis
news_articles_df['pub_date'] = pd.to_datetime(news_articles_df['pub_date']).apply(lambda x: x.date())

# %%
#look for missing data
news_articles_df.isnull().sum()
# Out:
# author         11
# content         0
# description     0
# photo_url       1
# pub_date        0
# source          0
# title           0
# url             0
# dtype: int64

# %% [markdown]
# We can see that there are quite a few missing values present in the dataset and since the dataset is purely textual in nature and given the type of fields having the missing value, it is not possible to fill the missing values in this case hence I dicided to drop all rows with null values.

# %%
# droping the rows with missing data 
news_articles_df.dropna(inplace=True)
news_articles_df = news_articles_df[~news_articles_df['description'].isnull()]
# summarize the number of rows and columns in the dataset
print(news_articles_df.isnull().sum())
print(news_articles_df.shape)
# Out:
# author         0
# content        0
# description    0
# photo_url      0
# pub_date       0
# source         0
# title          0
# url            0
# dtype: int64
# (88, 8)

# %% [markdown]
# The title along with the content provided significant detail regarding the story and both columns contained some keywords which were essential for futher analysis hence they were combined to form one column

# %%
# combine the title and the content to get one dataframe column
news_articles_df['combined_text'] = news_articles_df['title'].map(str) +" "+ news_articles_df['content'].map(str)

# %%
news_articles_df
# Out:
#                                                author  \
# 0                                           Kris Holt
# 1                                      Igor Bonifacic
# 2                                          Jon Fingas
# 3                                      Igor Bonifacic
# 4                                           Kris Holt
# 5                                           Mat Smith
# 6                                       Mariella Moon
# 7                                           Mat Smith
# 8                                      Arielle Pardes
# 9                                   Noah Giansiracusa
# 10                                   Chisom Peter Job
# 11                                    Eleanor Cummins
# 12                                          Mar Hicks
# 13                                Ian Carlos Campbell
# 14                                     Richard Lawler
# 15                                         Alex Heath
# 16                                         Jon Porter
# 17                            Jennifer Pattison Tuohy
# 18                                         Alex Cranz
# 19                                      James Vincent
# 20                                         Jay Peters
# 21                                     Nicole Wetsman
# 22                                         Jon Porter
# 23                                      Adi Robertson
# 24                                        Nilay Patel
# 25                      noreply@blogger.com (Unknown)
# 26                      noreply@blogger.com (Unknown)
# 27                      noreply@blogger.com (Unknown)
# 28                                       Brian Heater
# 30                                    Taylor Hatmaker
# ..                                                ...
# 59                                 The New York Times
# 60                  Joshua Hammer and Jason Gutierrez
# 61                   https://www.facebook.com/bbcnews
# 62                   https://www.facebook.com/bbcnews
# 63                   https://www.facebook.com/bbcnews
# 64                   https://www.facebook.com/bbcnews
# 65                   https://www.facebook.com/bbcnews
# 66                     Donie O'Sullivan, CNN Business
# 67  Samantha Murphy Kelly and Clare Duffy, CNN Bus...
# 68                               Jen Christensen, CNN
# 69                              Francesca Street, CNN
# 70      Ryan Young, Jason Morris and Ray Sanchez, CNN
# 71                   https://www.facebook.com/bbcnews
# 72                   https://www.facebook.com/bbcnews
# 73                   https://www.facebook.com/bbcnews
# 74                   https://www.facebook.com/bbcnews
# 75                   https://www.facebook.com/bbcnews
# 76                   https://www.facebook.com/bbcnews
# 77                   https://www.facebook.com/bbcnews
# 78                                         Jim Salter
# 79                                       Tim De Chant
# 80                                       Tim De Chant
# 81            Chanelle GarciaGoogle Web Creators team
# 82            Chanelle GarciaGoogle Web Creators team
# 83                                        Stadia Team
# 84                                  Reuters Editorial
# 86                                        Sheila Dang
# 88   Nafisa Eltahir, Malaika Tapper, Khalid Abdelaziz
# 91                                      Reuters Staff
# 98                                        Sheila Dang
#
#                                               content  \
# 0   Some Snapchat users are having problems with t...
# 1   If you can't access Facebook, Instagram, Messe...
# 2   Facebook is about to close an important chapte...
# 3   Following Mondays massive service outage that ...
# 4   Facebook\r\n will soon let folks who still hav...
# 5   Welcome to Monday. How was your weekend? For m...
# 6   2Africa, a subsea cable project funded by Face...
# 7   Well get into why Facebook saw its entire busi...
# 8   The return of tech conferences began not with ...
# 9   In public, Facebook seems to claim that it rem...
# 10  Tomiwa Ibukunle, a 21-year-old entrepreneur in...
# 11  A trove of leaked documents and a recent congr...
# 12  But the idea that Facebooks technological unde...
# 13  Filed under:\r\nKicking another social network...
# 14  Its probably DNS\r\nIllustration by Alex Castr...
# 15  Engineers have been sent to a California data ...
# 16  Giving users full root access\r\nThe Oculus Go...
# 17  If you buy something from a Verge link, Vox Me...
# 18  The claims are in response to a damning Wall S...
# 19  The browser extension essentially wiped users ...
# 20  Tough week for Facebook\r\nIllustration by Ale...
# 21  Efforts to minimize the findings arent good fo...
# 22  Encrypted messaging app Signal also reports ga...
# 23  HTC wants to find a new VR market — but what i...
# 24  Photo Illustration by Grayson Blackmon / The V...
# 25  Users also reported issues with Facebook’s onl...
# 26  Facebook is continuing to have one of its long...
# 27  If Mark Zuckerberg’s “juvenile jottings” on pr...
# 28  The Portal line has always been a kind of odd ...
# 30  Ben Rubin understands where social is going. I...
# ..                                                ...
# 59  Daily Covid Briefing\r\nOct. 9, 2021Updated Oc...
# 60  LiveUpdated Oct. 8, 2021, 7:22 a.m. ET\r\nOct....
# 61  image source, Getty Images\r\nIn our series of...
# 62  By Mark SavageBBC Music Correspondent\r\nimage...
# 63  Image caption, Ferdinand Marcos Jr - seen with...
# 64  By BBC MonitoringEssential Media Insight\r\nim...
# 65  By Mark SavageBBC Music Correspondent\r\nimage...
# 66  San Francisco (CNN Business)Sophie Zhang, who ...
# 67  (CNN Business)The Facebook whistleblower who r...
# 68  (CNN)Being a nurse means everything to Andrea ...
# 69  (CNN) Ignacio Nieto Carvajal and Miguel Piñas ...
# 70  (CNN)Jessica Desfosses shared the final heartr...
# 71  Image source, Getty Images\r\nImage caption, F...
# 72  By Mark SavageBBC Music Correspondent\r\nimage...
# 73  By Niall GlynnBBC News NI \r\nImage source, Ri...
# 74  Image source, Getty Images\r\nImage caption, D...
# 75  Image source, Ashley Cooper GWI\r\nImage capti...
# 76  By Annabel RackhamNewsbeat reporter\r\n"Everyo...
# 77  By BBC MonitoringEssential Media Insight\r\nim...
# 78  Enlarge/ Today's global Facebook and Facebook-...
# 79  Enlarge/ Former Facebook employee Frances Haug...
# 80  Enlarge/ Facebook CEO Mark Zuckerberg testifyi...
# 81  She founded Andi Eaton Creatives, a team of di...
# 82  Eden Hagos grew up in Windsor, Ontario, Canada...
# 83  In September, the Stadia Pro library grew to m...
# 84  Posted \r\nThe $920 bln social network is figh...
# 86  (Reuters) - Facebook Inc said on Wednesday it ...
# 88  CAIRO/KHARTOUM (Reuters) - Facebook says it ha...
# 91  By Reuters Staff\r\nA look at the day ahead fr...
# 98  FILE PHOTO: Attendees walk past a Facebook log...
#
#                                           description  \
# 0   Some Snapchat users are having problems with t...
# 1   If you can't access Facebook, Instagram, Messe...
# 2   Facebook is about to close an important chapte...
# 3   Following Monday’s massive service outage that...
# 4   Facebook\r\n will soon let folks who still hav...
# 5   Welcome to Monday. How was your weekend? For m...
# 6   2Africa, a subsea cable project funded by Face...
# 7   We’ll get into why Facebook saw its entire bus...
# 8   Hundreds of (vaccinated) attendees gathered in...
# 9   The company publicly claims its AI is amazing ...
# 10  The platform's shutdown sparked uncertainty an...
# 11  It's almost inevitable that social media force...
# 12  Before there was Big Tech, there were auto com...
# 13  Twitter CEO Jack Dorsey is dunking on Facebook...
# 14  Facebook, Instagram, WhatsApp, and Messenger a...
# 15  Engineers have been sent to a California data ...
# 16  Facebook is unlocking the software and bootloa...
# 17  The Portal Go from Facebook is excellent as a ...
# 18  Ahead of a Senate committee hearing Facebook’s...
# 19  Louis Barclay, the developer behind the Unfoll...
# 20  Facebook said that some of its services are ex...
# 21  Internal research at Facebook showing that Ins...
# 22  Messaging app Telegram gained a record 70 mill...
# 23  HTC has announced the Vive Flow, a $499 virtua...
# 24  Jeep CEO Christian Meunier talks about the new...
# 25  Social media platforms Facebook, Instagram and...
# 26  Facebook is continuing to have one of its long...
# 27  If Mark Zuckerberg’s “juvenile jottings” on pr...
# 28  The Portal line has always been a kind of odd ...
# 30  Ben Rubin understands where social is going. I...
# ..                                                ...
# 59  “The pressure on hospitals and clinics in both...
# 60  In an era of increasing authoritarianism and s...
# 61  Ethiopian and Eritrean food is well known glob...
# 62  The Foo Fighters star says his whole life is a...
# 63  Ferdinand Marcos Jr's father was accused of wi...
# 64  One wildly inaccurate claim suggests Germany d...
# 65  The five-week trial heard harrowing details of...
# 66  Sophie Zhang, who said she felt like she had "...
# 67  The Facebook whistleblower who released tens o...
# 68  Being a nurse means everything to Andrea Babin...
# 69  Ignacio Nieto Carvajal and Miguel Piñas Rodríg...
# 70  The coronavirus has become the leading cause o...
# 71  A former employee tells the US Senate that the...
# 72  The pop star is joining Abba's live band next ...
# 73  Thousands of small spiders have been spotted o...
# 74  Why the need to be a people's representative a...
# 75  The half-eaten food and glasses of fizz were f...
# 76  Call Her Daddy host Alex Cooper has re-launche...
# 77  Newspapers across Europe are watching the knif...
# 78  The root cause of the worldwide outage appears...
# 79  Section 230 reform is just a start, Frances Ha...
# 80  Executive concerns of “over-enforcement” let h...
# 81  Every morning at 7 a.m, you’ll find Andi Eaton...
# 82  Eden Hagos grew up in Windsor, Ontario, Canada...
# 83  It’s time for another update to our Stadia Sav...
# 84  The $920 bln social network is fighting on mul...
# 86  Facebook Inc said on Wednesday it is underrepo...
# 88  Facebook says it has shut down two large netwo...
# 91  U.S. and European bond yields are up sharply, ...
# 98  Facebook Inc on Thursday said it reduces the d...
#
#                                             photo_url    pub_date  \
# 0   https://s.yimg.com/os/creatr-images/2019-06/1b...  2021-10-13
# 1   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04
# 2   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-22
# 3   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-05
# 4   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-27
# 5   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04
# 6   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-28
# 7   https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-06
# 8   https://media.wired.com/photos/615607db296d418...  2021-10-01
# 9   https://media.wired.com/photos/6168c9b0c12c627...  2021-10-15
# 10  https://media.wired.com/photos/61644befd5b17ce...  2021-10-11
# 11  https://media.wired.com/photos/6160e0d27d0472a...  2021-10-10
# 12  https://media.wired.com/photos/6164e61a15502b8...  2021-10-14
# 13  https://cdn.vox-cdn.com/thumbor/dn50zT86uS4Kmr...  2021-10-04
# 14  https://cdn.vox-cdn.com/thumbor/BX718uWWEZPX7s...  2021-10-04
# 15  https://cdn.vox-cdn.com/thumbor/KqmvMUzxiqwsVn...  2021-10-04
# 16  https://cdn.vox-cdn.com/thumbor/jwK3_Qmzq-mUHx...  2021-09-27
# 17  https://cdn.vox-cdn.com/thumbor/IbbRKQHBHSEIJv...  2021-10-19
# 18  https://cdn.vox-cdn.com/thumbor/AhEDh8cXLzPzD8...  2021-09-27
# 19  https://cdn.vox-cdn.com/thumbor/BX718uWWEZPX7s...  2021-10-08
# 20  https://cdn.vox-cdn.com/thumbor/GD8_ddV1_zZQH7...  2021-10-08
# 21  https://cdn.vox-cdn.com/thumbor/AhEDh8cXLzPzD8...  2021-10-06
# 22  https://cdn.vox-cdn.com/thumbor/ma3VFJyH8a5RbM...  2021-10-06
# 23  https://cdn.vox-cdn.com/thumbor/WdAguvf8zZvG0m...  2021-10-14
# 24  https://cdn.vox-cdn.com/thumbor/W_OuY_Xlg2l3_I...  2021-10-19
# 25  https://blogger.googleusercontent.com/img/a/AV...  2021-10-04
# 26  https://lh6.googleusercontent.com/proxy/qBgVib...  2021-10-04
# 27  https://blogger.googleusercontent.com/img/a/AV...  2021-10-08
# 28  https://techcrunch.com/wp-content/uploads/2021...  2021-09-21
# 30  https://techcrunch.com/wp-content/uploads/2021...  2021-09-21
# ..                                                ...         ...
# 59  https://static01.nyt.com/images/2021/10/08/mul...  2021-10-09
# 60  https://static01.nyt.com/images/2021/10/08/wor...  2021-10-08
# 61  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-25
# 62  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-29
# 63  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-05
# 64  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-24
# 65  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-24
# 66  https://cdn.cnn.com/cnnnext/dam/assets/2110111...  2021-10-12
# 67  https://cdn.cnn.com/cnnnext/dam/assets/2110032...  2021-10-05
# 68  https://cdn.cnn.com/cnnnext/dam/assets/2107140...  2021-10-01
# 69  https://cdn.cnn.com/cnnnext/dam/assets/2109221...  2021-09-29
# 70  https://cdn.cnn.com/cnnnext/dam/assets/2110160...  2021-10-16
# 71  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-05
# 72  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-24
# 73  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-18
# 74  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-16
# 75  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-14
# 76  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-10-11
# 77  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-09-27
# 78  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-04
# 79  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-06
# 80  https://cdn.arstechnica.net/wp-content/uploads...  2021-10-18
# 81  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-04
# 82  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-18
# 83  https://storage.googleapis.com/gweb-uniblog-pu...  2021-10-04
# 84  https://static.reuters.com/resources/r/?d=2021...  2021-10-05
# 86  https://static.reuters.com/resources/r/?m=02&d...  2021-09-22
# 88  https://static.reuters.com/resources/r/?m=02&d...  2021-10-19
# 91  https://static.reuters.com/resources/r/?m=02&d...  2021-10-06
# 98  https://static.reuters.com/resources/r/?m=02&d...  2021-09-23
#
#             source                                              title  \
# 0         Engadget                                   Snapchat is down
# 1         Engadget  Facebook is down, along with Instagram, WhatsA...
# 2         Engadget  Facebook's chief technology officer is leaving...
# 3         Engadget  Facebook explains how its October 4th outage s...
# 4         Engadget  Facebook will open up the Oculus Go to tinkere...
# 5         Engadget  The Morning After: What is it with Netflix cro...
# 6         Engadget  Facebook's 2Africa to become the longest subse...
# 7         Engadget  The Morning After: Facebook's October 4th outa...
# 8            Wired  With Fist Bumps and Nasal Swabs, Tech Conferen...
# 9            Wired  How Facebook Hides How Terrible It Is With Hat...
# 10           Wired  In Nigeria, Facebook's Outage Revealed a Dange...
# 11           Wired             Bodies Are Canceled. Thanks, Instagram
# 12           Wired  Facebook's Fall From Grace Looks a Lot Like Fo...
# 13       The Verge  Twitter is up, Facebook is down, and Jack Dors...
# 14       The Verge  Facebook is down, along with Instagram, WhatsA...
# 15       The Verge  Locked out and totally down: Facebook is scram...
# 16       The Verge  The Oculus Go’s operating system is being unlo...
# 17       The Verge  Facebook’s new Portal Go is great for video ca...
# 18       The Verge  Facebook says Instagram is not ‘toxic for teen...
# 19       The Verge  Facebook bans developer behind Unfollow Everyt...
# 20       The Verge  Facebook confirms that some of its services ar...
# 21       The Verge  Facebook’s whistleblower report confirms what ...
# 22       The Verge  Telegram gains 70M new users in just one day a...
# 23       The Verge  The $499 HTC Vive Flow is VR for people who do...
# 24       The Verge  How Jeep is going electric, with CEO Christian...
# 25    Blogspot.com  Facebook Instagram And Whatsapp Hit by Global ...
# 26    Blogspot.com  Here's What We Know About The Facebook Outage ...
# 27    Blogspot.com  Zuckerberg’s Early Notes on Privacy Now Haunt ...
# 28      TechCrunch  Facebook adds a battery-powered smart screen t...
# 30      TechCrunch  Ben Rubin, who founded Houseparty, Meerkat and...
# ..             ...                                                ...
# 59  New York Times  Delta-Driven Surge Pushes North Dakota Hospita...
# 60  New York Times  Philippine journalist Maria Ressa has incurred...
# 61        BBC News  Letter from Africa: The wonders of Somali cuis...
# 62        BBC News  Dave Grohl: My whole life is like an out-of-bo...
# 63        BBC News  Philippines: Son of ex-dictator Marcos to run ...
# 64        BBC News  German elections 2021: The conspiracy theories...
# 65        BBC News  R. Kelly trial: A look at the key moments as j...
# 66             CNN  Another Facebook whistleblower says she is wil...
# 67             CNN  Facebook whistleblower to testify in Senate he...
# 68             CNN  The Covid-19 vaccine health care worker holdou...
# 69             CNN          Traveling the world as gay digital nomads
# 70             CNN  Five times as many police officers have died f...
# 71        BBC News  Facebook harms children and weakens democracy:...
# 72        BBC News  Little Boots says Abba's new live band is 'bad...
# 73        BBC News           Invasion of the ballooning money spiders
# 74        BBC News  Sir David Amess killing: Security for politici...
# 75        BBC News  Lake District mysterious abandoned tea-for-two...
# 76        BBC News  Call Her Daddy's Alex Cooper: 'Not everyone ca...
# 77        BBC News     Papers gripped by Germany's era of uncertainty
# 78    Ars Technica  Facebook, Instagram, WhatsApp, and Oculus are ...
# 79    Ars Technica  Algorithms shouldn’t be protected by Section 2...
# 80    Ars Technica  Facebook AI moderator confused videos of mass ...
# 81     Blog.google                 Finding a niche in holistic living
# 82     Blog.google  Building community and bridges through Black f...
# 83     Blog.google                Stadia Savepoint: September updates
# 84         Reuters               BVTV: Facebook under siege - Reuters
# 86         Reuters  Facebook warns it is 'underreporting' iOS ad r...
# 88         Reuters  Facebook shuts fake accounts in Sudan, as figh...
# 91         Reuters  Marketmind: Hunker down, it's going to be one ...
# 98         Reuters  Facebook explains content it demotes in news f...
#
#                                                   url  \
# 0   https://www.engadget.com/snapchat-down-error-o...
# 1   https://www.engadget.com/facebook-instagram-wh...
# 2   https://www.engadget.com/facebook-cto-steps-do...
# 3   https://www.engadget.com/facebook-outage-expla...
# 4   https://www.engadget.com/facebook-oculus-go-op...
# 5   https://www.engadget.com/the-morning-after-wha...
# 6   https://www.engadget.com/facebook-2-africa-lon...
# 7   https://www.engadget.com/the-morning-after-fac...
# 8   https://www.wired.com/story/fist-bumps-nasal-s...
# 9   https://www.wired.com/story/facebooks-deceptiv...
# 10  https://www.wired.com/story/nigeria-whatsapp-f...
# 11  https://www.wired.com/story/instagram-mental-h...
# 12  https://www.wired.com/story/facebook-ford-fall...
# 13  https://www.theverge.com/tldr/2021/10/4/227092...
# 14  https://www.theverge.com/2021/10/4/22708989/in...
# 15  https://www.theverge.com/2021/10/4/22709575/fa...
# 16  https://www.theverge.com/2021/9/27/22696030/oc...
# 17  https://www.theverge.com/22732472/facebook-por...
# 18  https://www.theverge.com/2021/9/26/22695629/fa...
# 19  https://www.theverge.com/2021/10/8/22716044/fa...
# 20  https://www.theverge.com/2021/10/8/22716860/fa...
# 21  https://www.theverge.com/2021/10/6/22712927/fa...
# 22  https://www.theverge.com/2021/10/6/22712191/te...
# 23  https://www.theverge.com/2021/10/14/22713276/h...
# 24  https://www.theverge.com/22733877/jeep-ceo-dec...
# 25  https://techncruncher.blogspot.com/2021/10/fac...
# 26  https://techncruncher.blogspot.com/2021/10/her...
# 27  https://techncruncher.blogspot.com/2021/10/zuc...
# 28  http://techcrunch.com/2021/09/21/facebook-adds...
# 30  http://techcrunch.com/2021/09/21/ben-rubin-dis...
# ..                                                ...
# 59  https://www.nytimes.com/live/2021/10/09/world/...
# 60  https://www.nytimes.com/live/2021/10/08/world/...
# 61   https://www.bbc.co.uk/news/world-africa-58348779
# 62  https://www.bbc.co.uk/news/entertainment-arts-...
# 63     https://www.bbc.co.uk/news/world-asia-58807694
# 64   https://www.bbc.co.uk/news/world-europe-58655702
# 65  https://www.bbc.co.uk/news/entertainment-arts-...
# 66  https://www.cnn.com/2021/10/11/tech/facebook-w...
# 67  https://www.cnn.com/2021/10/05/tech/facebook-w...
# 68  https://www.cnn.com/2021/09/30/health/unvaccin...
# 69  https://www.cnn.com/travel/article/ignacio-mig...
# 70  https://www.cnn.com/2021/10/16/us/police-vacci...
# 71  https://www.bbc.co.uk/news/world-us-canada-588...
# 72  https://www.bbc.co.uk/news/entertainment-arts-...
# 73  https://www.bbc.co.uk/news/uk-northern-ireland...
# 74          https://www.bbc.co.uk/news/world-58937581
# 75  https://www.bbc.co.uk/news/uk-england-cumbria-...
# 76       https://www.bbc.co.uk/news/newsbeat-58719364
# 77   https://www.bbc.co.uk/news/world-europe-58706549
# 78  https://arstechnica.com/information-technology...
# 79  https://arstechnica.com/tech-policy/2021/10/al...
# 80  https://arstechnica.com/tech-policy/2021/10/fa...
# 81  https://blog.google/web-creators/finding-niche...
# 82  https://blog.google/web-creators/building-comm...
# 83  https://blog.google/products/stadia/savepoint-...
# 84    https://www.reuters.com/video/watch/idRCV00AANP
# 86  https://www.reuters.com/article/facebook-adver...
# 88  https://www.reuters.com/article/us-sudan-faceb...
# 91  https://www.reuters.com/article/markets-europe...
# 98  https://www.reuters.com/article/facebook-moder...
#
#                                         combined_text
# 0   Snapchat is down Some Snapchat users are havin...
# 1   Facebook is down, along with Instagram, WhatsA...
# 2   Facebook's chief technology officer is leaving...
# 3   Facebook explains how its October 4th outage s...
# 4   Facebook will open up the Oculus Go to tinkere...
# 5   The Morning After: What is it with Netflix cro...
# 6   Facebook's 2Africa to become the longest subse...
# 7   The Morning After: Facebook's October 4th outa...
# 8   With Fist Bumps and Nasal Swabs, Tech Conferen...
# 9   How Facebook Hides How Terrible It Is With Hat...
# 10  In Nigeria, Facebook's Outage Revealed a Dange...
# 11  Bodies Are Canceled. Thanks, Instagram A trove...
# 12  Facebook's Fall From Grace Looks a Lot Like Fo...
# 13  Twitter is up, Facebook is down, and Jack Dors...
# 14  Facebook is down, along with Instagram, WhatsA...
# 15  Locked out and totally down: Facebook is scram...
# 16  The Oculus Go’s operating system is being unlo...
# 17  Facebook’s new Portal Go is great for video ca...
# 18  Facebook says Instagram is not ‘toxic for teen...
# 19  Facebook bans developer behind Unfollow Everyt...
# 20  Facebook confirms that some of its services ar...
# 21  Facebook’s whistleblower report confirms what ...
# 22  Telegram gains 70M new users in just one day a...
# 23  The $499 HTC Vive Flow is VR for people who do...
# 24  How Jeep is going electric, with CEO Christian...
# 25  Facebook Instagram And Whatsapp Hit by Global ...
# 26  Here's What We Know About The Facebook Outage ...
# 27  Zuckerberg’s Early Notes on Privacy Now Haunt ...
# 28  Facebook adds a battery-powered smart screen t...
# 30  Ben Rubin, who founded Houseparty, Meerkat and...
# ..                                                ...
# 59  Delta-Driven Surge Pushes North Dakota Hospita...
# 60  Philippine journalist Maria Ressa has incurred...
# 61  Letter from Africa: The wonders of Somali cuis...
# 62  Dave Grohl: My whole life is like an out-of-bo...
# 63  Philippines: Son of ex-dictator Marcos to run ...
# 64  German elections 2021: The conspiracy theories...
# 65  R. Kelly trial: A look at the key moments as j...
# 66  Another Facebook whistleblower says she is wil...
# 67  Facebook whistleblower to testify in Senate he...
# 68  The Covid-19 vaccine health care worker holdou...
# 69  Traveling the world as gay digital nomads (CNN...
# 70  Five times as many police officers have died f...
# 71  Facebook harms children and weakens democracy:...
# 72  Little Boots says Abba's new live band is 'bad...
# 73  Invasion of the ballooning money spiders By Ni...
# 74  Sir David Amess killing: Security for politici...
# 75  Lake District mysterious abandoned tea-for-two...
# 76  Call Her Daddy's Alex Cooper: 'Not everyone ca...
# 77  Papers gripped by Germany's era of uncertainty...
# 78  Facebook, Instagram, WhatsApp, and Oculus are ...
# 79  Algorithms shouldn’t be protected by Section 2...
# 80  Facebook AI moderator confused videos of mass ...
# 81  Finding a niche in holistic living She founded...
# 82  Building community and bridges through Black f...
# 83  Stadia Savepoint: September updates In Septemb...
# 84  BVTV: Facebook under siege - Reuters Posted \r...
# 86  Facebook warns it is 'underreporting' iOS ad r...
# 88  Facebook shuts fake accounts in Sudan, as figh...
# 91  Marketmind: Hunker down, it's going to be one ...
# 98  Facebook explains content it demotes in news f...
#
# [88 rows x 9 columns]

# %% [markdown]
# Applying Text Preprocessing steps:
# In the followting sections, some of the text preprocessing steps were applied to the data. The steps included:
# 1. Tokenization
# 2. Removing the non ASCII characters from the text
# 3. Stop words removal
# 4. Removing punctuations, apostrophe, special characters etc
# 5. lemmatize the text

# %%
# Function to remove non-ascii characters from the text
def _removeNonAscii(s): 
    return "".join(i for i in s if ord(i)<128)
# function to remove the punctuations, apostrophe, special characters using regular expressions
def clean_text(text):
    text = text.lower()
    text = re.sub(r"what's", "what is ", text)
    text = text.replace('(ap)', '')
    text = re.sub(r"\'s", " is ", text)
    text = re.sub(r"\'ve", " have ", text)
    text = re.sub(r"can't", "cannot ", text)
    text = re.sub(r"n't", " not ", text)
    text = re.sub(r"i'm", "i am ", text)
    text = re.sub(r"\'re", " are ", text)
    text = re.sub(r"\'d", " would ", text)
    text = re.sub(r"\'ll", " will ", text)
    text = re.sub(r'\W+', ' ', text)
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r"\\", "", text)
    text = re.sub(r"\'", "", text)    
    text = re.sub(r"\"", "", text)
    text = re.sub('[^a-zA-Z ?!]+', '', text)
    text = _removeNonAscii(text)
    text = text.strip()
    return text
# stop words are the words that convery little to no information about the actual content like the words:the, of, for etc
def remove_stopwords(word_tokens):
    filtered_sentence = [] 
    stop_words = stopwords.words('english')
    specific_words_list = ['char', 'u', 'hindustan', 'doj', 'washington'] 
    stop_words.extend(specific_words_list )
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 
    return filtered_sentence
# function for lemmatization 
def lemmatize(x):
    lemmatizer = WordNetLemmatizer()
    return' '.join([lemmatizer.lemmatize(word) for word in x])

# %%
# splitting a string, text into a list of tokens
tokenizer = RegexpTokenizer(r'\w+')
def tokenize(x): 
    return tokenizer.tokenize(x)

# %%
#nltk.download('stopwords')
#nltk.download('wordnet')
# applying all of these functions to the our dataframe 
news_articles_df['combined_text'] = news_articles_df['combined_text'].map(clean_text)
news_articles_df['tokens'] = news_articles_df['combined_text'].map(tokenize)
news_articles_df['tokens'] = news_articles_df['tokens'].map(remove_stopwords)
news_articles_df['lems'] =news_articles_df['tokens'].map(lemmatize)

# %%
news_articles_df.head()
# Out:
#            author                                            content  \
# 0       Kris Holt  Some Snapchat users are having problems with t...
# 1  Igor Bonifacic  If you can't access Facebook, Instagram, Messe...
# 2      Jon Fingas  Facebook is about to close an important chapte...
# 3  Igor Bonifacic  Following Mondays massive service outage that ...
# 4       Kris Holt  Facebook\r\n will soon let folks who still hav...
#
#                                          description  \
# 0  Some Snapchat users are having problems with t...
# 1  If you can't access Facebook, Instagram, Messe...
# 2  Facebook is about to close an important chapte...
# 3  Following Monday’s massive service outage that...
# 4  Facebook\r\n will soon let folks who still hav...
#
#                                            photo_url    pub_date    source  \
# 0  https://s.yimg.com/os/creatr-images/2019-06/1b...  2021-10-13  Engadget
# 1  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-04  Engadget
# 2  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-22  Engadget
# 3  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-10-05  Engadget
# 4  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-09-27  Engadget
#
#                                                title  \
# 0                                   Snapchat is down
# 1  Facebook is down, along with Instagram, WhatsA...
# 2  Facebook's chief technology officer is leaving...
# 3  Facebook explains how its October 4th outage s...
# 4  Facebook will open up the Oculus Go to tinkere...
#
#                                                  url  \
# 0  https://www.engadget.com/snapchat-down-error-o...
# 1  https://www.engadget.com/facebook-instagram-wh...
# 2  https://www.engadget.com/facebook-cto-steps-do...
# 3  https://www.engadget.com/facebook-outage-expla...
# 4  https://www.engadget.com/facebook-oculus-go-op...
#
#                                        combined_text  \
# 0  snapchat is down some snapchat users are havin...
# 1  facebook is down along with instagram whatsapp...
# 2  facebook is chief technology officer is leavin...
# 3  facebook explains how its october th outage st...
# 4  facebook will open up the oculus go to tinkere...
#
#                                               tokens  \
# 0  [snapchat, snapchat, users, problems, app, mor...
# 1  [facebook, along, instagram, whatsapp, messeng...
# 2  [facebook, chief, technology, officer, leaving...
# 3  [facebook, explains, october, th, outage, star...
# 4  [facebook, open, oculus, go, tinkerers, unlock...
#
#                                                 lems
# 0  snapchat snapchat user problem app morning sev...
# 1  facebook along instagram whatsapp messenger ca...
# 2  facebook chief technology officer leaving comp...
# 3  facebook explains october th outage started fo...
# 4  facebook open oculus go tinkerer unlocked o fa...

# %%
# finding the keywords using the rake algorithm from NLTK
# rake is Rapid Automatic Keyword Extraction algorithm, and is used for domain independent keyword extraction
nltk.download('punkt')
news_articles_df['keywords'] = ""
for index,row in news_articles_df.iterrows():
    comb_text = row['combined_text']
    r = Rake()
    r.extract_keywords_from_text(comb_text)
    key_words_dict = r.get_word_degrees()
    row['keywords'] = list(key_words_dict.keys())
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# applying the fucntion to the dataframe
news_articles_df['keywords'] = news_articles_df['keywords'].map(remove_stopwords)
news_articles_df['lems'] =news_articles_df['keywords'].map(lemmatize)

# %%
news_articles_df.head()
news_articles_df.to_csv('data/news_articles_clean1.csv', index = False)

# %% [markdown]
# Note: This completed one phase of data collecton step. Exact same process was followed with just the change in date in order to get the news articles of a date beyond 1 month. Including the same proceduce twice would have made it redundant hence I have directly included the two CSV files directly.

# %% [markdown]
# ##### Combining the data collected in two phases

# %%
#Combining the collected data
# dataframe1 contains the articles from 15th Sep to 15 Oct 
dataframe1=pd.read_csv("data/news_articles_clean1.csv")

#dataframe2=pd.read_csv("data/news_articles_secondgo.csv")
# dataframe2 contains the articles from 14 March to 29th March 
dataframe_combined_data = dataframe1

# %%
dataframe_combined_data.to_csv('data/news_articles_combined1.csv', index = False)

# %%
# reading the new combined data in the news_articles dataframe
news_articles_df = pd.read_csv("data/news_articles_combined1.csv")

# %%
# Checking the combined data once again to ensure no null value is present
print(news_articles_df.isnull().sum())
news_articles_df.dropna(inplace=True)
print(news_articles_df.shape)
print(news_articles_df.isnull().sum())
# Out:
# author           0
# content          0
# description      0
# photo_url        0
# pub_date         0
# source           0
# title            0
# url              0
# combined_text    0
# tokens           0
# lems             0
# keywords         0
# dtype: int64
# (88, 12)
# author           0
# content          0
# description      0
# photo_url        0
# pub_date         0
# source           0
# title            0
# url              0
# combined_text    0
# tokens           0
# lems             0
# keywords         0
# dtype: int64

# %% [markdown]
# ### Task 4: Sentiment Analysis of News articles to answer our Questions

# %%
nltk.download('vader_lexicon')
# calculating the polarity of the news articles 
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
sia = SIA()
results = []
for line in news_articles_df['lems'] :
    pol_score = sia.polarity_scores(line)
    pol_score['headline'] = line
    results.append(pol_score)
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Creating a new dataframe of only the polarity score, the headline and the source of the news 
headlines_polarity = pd.DataFrame.from_records(results)
temp = []
for line in news_articles_df['source'] :
    temp.append(line)
headlines_polarity['source'] =temp

# %%
# categorize news as positive or negative based on the compound score obtained
headlines_polarity['label'] = 0
# I have considered the news as positive if the compound score is greater than 0.2 hence the label 1
headlines_polarity.loc[headlines_polarity['compound'] > 0.2, 'label'] = 1
# if the compound score is below 0.2 then it is considered negative 
headlines_polarity.loc[headlines_polarity['compound'] < -0.2, 'label'] = -1
# word count of news headlines is calculated
headlines_polarity['word_count'] = headlines_polarity['headline'].apply(lambda x: len(str(x).split()))

# %%
headlines_polarity.head()
# Out:
#    compound                                           headline    neg    neu  \
# 0   -0.4019  snapchat user problem app morning several noti...  0.144  0.856
# 1    0.0000  facebook along instagram whatsapp messenger ca...  0.000  1.000
# 2    0.2023  facebook chief technology officer leaving comp...  0.000  0.917
# 3    0.0000  facebook explains october th outage started fo...  0.000  1.000
# 4    0.0000  facebook open oculus go tinkerer unlocked o so...  0.000  1.000
#
#      pos    source  label  word_count
# 0  0.000  Engadget     -1          17
# 1  0.000  Engadget      0          21
# 2  0.083  Engadget      1          21
# 3  0.000  Engadget      0          25
# 4  0.000  Engadget      0          23

# %%
#headlines_polarity.label.value_counts()
#headlines_polarity.groupby('source').label.value_counts()
# Grouping the news articles by their source and calculating their mean polarity  
gk = headlines_polarity.groupby(['source', 'label']) 
fk= headlines_polarity.groupby('source')['compound'].mean()
fk = fk.to_frame()
fk.to_csv('data/mean_polarity1.csv', index = 'source')

# %% [markdown]
# ### Visualizations

# %%
#pip install textblob

# %%
#pip install plotly

# %%
#pip install chart_studio

# %%
#pip install cufflinks

# %%
#pip install wordcloud

# %%
#pip install scattertext

# %%
# libraries
import pandas as pd
import numpy as np
from textblob import TextBlob
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
import warnings 
warnings.filterwarnings('ignore')
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (10.0, 6.0)
import plotly.graph_objs as go
#import plotly.plotly as py
import chart_studio.plotly as py
import cufflinks
pd.options.display.max_columns = 30
from IPython.core.interactiveshell import InteractiveShell
import plotly.figure_factory as ff
InteractiveShell.ast_node_interactivity = 'all'
from plotly.offline import iplot
cufflinks.go_offline()
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import scattertext as st
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.4.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize=(8, 8))
counts = headlines_polarity.label.value_counts(normalize=True) * 100
sns.barplot(x=counts.index, y=counts, ax=ax)
ax.set_xticklabels(['Negative', 'Neutral', 'Positive'])
ax.set_ylabel("Percentage")
plt.show()
# Out:
# [Text(0, 0, 'Negative'), Text(0, 0, 'Neutral'), Text(0, 0, 'Positive')]
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# <font color='red'>Insights:</font> It is clear from the above bar chart that the distribution of news is quite even when it comes to the polarity of the news. Both Positive and negative sentiment accounted for about 40% each despite the time frame in which the newss articles were collected. At the prima facie level, this goes on to show that the media outlets are not biased towards the negative news.

# %%
headlines_polarity['compound'].iplot(
    kind='hist',
    bins=30,
    xTitle='polarity',
    linecolor='black',
    yTitle='count',
    title='Sentiment Polarity Distribution')
# Out:
# <div>                            <div id="d2b1fb35-f59b-425a-b984-5b1a1161b5b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("d2b1fb35-f59b-425a-b984-5b1a1161b5b3")) {                    Plotly.newPlot(                        "d2b1fb35-f59b-425a-b984-5b1a1161b5b3",                        [{"histfunc":"count","histnorm":"","marker":{"color":"rgba(255, 153, 51, 1.0)","line":{"color":"#000000","width":1.3}},"name":"compound","nbinsx":30,"opacity":0.8,"orientation":"v","type":"histogram","x":[-0.4019,0.0,0.2023,0.0,0.0,0.4019,0.0,0.2732,0.0,-0.8176,-0.3182,-0.4404,0.6486,0.4939,0.0,0.0,0.34,0.8625,-0.3744,-0.1027,-0.4939,-0.7968,0.8316,0.802,0.0,-0.4019,-0.4939,-0.4019,0.7722,0.2732,0.4215,0.743,0.0,0.34,0.1779,-0.4019,0.4939,-0.7351,-0.296,0.296,-0.3818,-0.296,-0.7536,-0.4939,0.4404,-0.4019,0.0258,0.0,-0.296,-0.836,0.3182,0.3182,-0.4588,-0.6124,0.3182,0.0,0.0,-0.7845,0.4215,-0.3182,-0.2023,0.3612,0.0,-0.5267,-0.34,0.6908,-0.4019,0.7783,0.25,-0.296,-0.0258,0.4404,-0.5423,-0.5719,-0.1531,0.0772,-0.34,0.0,0.4404,-0.3182,0.5267,0.0,0.5994,-0.3612,-0.1027,-0.8519,0.0,0.0]}],                        {"barmode":"overlay","legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dc ...

# %% [markdown]
# <font color='red'>Insights:</font> The graph above shows the univariate polarity distribution of the news article headlines and it can be seen that the polarity score of the headlines is quite equally distributed across the range of 1 to -1. We have equal number of records on both sides of 0. Thus now we can reach a conclusion that though we often feel that only the negative news make it to the headlines, that is certainly not the case. It is our brain that is susceptible to this negativity bias, wherein we forget the positive side of the story and focus only on the negative side of it.

# %%
# Checking out the distribution of the news polarity based on the source of news
df_polarity = pd.read_csv('data/mean_polarity1.csv')
df_polarity = df_polarity.sort_values(['compound']).reset_index(drop=True)
fig, ax = plt.subplots(figsize=(14, 14))
ax = sns.barplot(x='compound', y='source', data=df_polarity)
ax.set_xlabel(' Mean Polarity')
ax.axvline(0.2)
ax.axvline(-0.2)
# Out:
# Text(0.5, 0, ' Mean Polarity')

# %% [markdown]
# <font color='red'>Insights:</font> The bar chart above shows mean polarity of some of the top news publishers from around the world.The two verical lines act a baseline to categorize whether the overall sentiment of the news is positive or negative. We can see that Bloomberg, Al Jazeera and BBC news have a negative mean polarity. which means these publishers genearally tend to cover stories that are negtive in its sentiments. Al jazeera mainly focuses on the war torn middle earth therfore, it is not surprising for it to have neagtive mean polarity. Bloomberg mainly covers the finance realted news or the news related to the stock market and one possible reason for it to have negative news polaity is Coronavirus Pandemic,  which has had a profound impact on the financial market in the last one month. However, It is surprising to find BBC on top of that list
# We can also see that the news publishers like Techcrunch and lifehacker which often focus on tech news have a positive mean polarity

# %%
# Box Plot for the top news publishers
y0 = headlines_polarity.loc[headlines_polarity['source'] == 'The Verge']['compound']
y1 = headlines_polarity.loc[headlines_polarity['source'] == 'BBC News']['compound']
y2 = headlines_polarity.loc[headlines_polarity['source'] == 'Wired']['compound']
y3 = headlines_polarity.loc[headlines_polarity['source'] == 'New York Times']['compound']
y4 = headlines_polarity.loc[headlines_polarity['source'] == 'Gizmodo.com']['compound']
y5 = headlines_polarity.loc[headlines_polarity['source'] == 'CNN']['compound']

trace0 = go.Box(
    y=y0,
    name = 'The Verge',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=y1,
    name = 'BBC',
    marker = dict(
        color = 'rgb(0, 150, 128)',
    )
)
trace2 = go.Box(
    y=y2,
    name = 'Wired',
    marker = dict(
        color = 'rgb(10, 140, 208)',
    )
)
trace3 = go.Box(
    y=y3,
    name = 'New York Times',
    marker = dict(
        color = 'rgb(12, 102, 14)',
    )
)
trace4 = go.Box(
    y=y4,
    name = 'Gizmodo.com',
    marker = dict(
        color = 'rgb(10, 0, 100)',
    )
)
trace5 = go.Box(
    y=y5,
    name = 'CNN',
    marker = dict(
        color = 'rgb(100, 0, 10)',
    )
)
data = [trace0, trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
    title = "Sentiment Polarity Boxplot of Popular News publishers"
)
fig = go.Figure(data=data,layout=layout)
iplot(fig, filename = "Sentiment Polarity Boxplot of Popular News publishers")
# Out:
# <div>                            <div id="a472eb8d-c444-4e7b-a97e-a9373efd3244" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a472eb8d-c444-4e7b-a97e-a9373efd3244")) {                    Plotly.newPlot(                        "a472eb8d-c444-4e7b-a97e-a9373efd3244",                        [{"marker":{"color":"rgb(214, 12, 140)"},"name":"The Verge","type":"box","y":[0.4939,0.0,0.0,0.34,0.8625,-0.3744,-0.1027,-0.4939,-0.7968,0.8316,0.802,0.0]},{"marker":{"color":"rgb(0, 150, 128)"},"name":"BBC","type":"box","y":[-0.2023,0.3612,0.0,-0.5267,-0.34,-0.0258,0.4404,-0.5423,-0.5719,-0.1531,0.0772,-0.34]},{"marker":{"color":"rgb(10, 140, 208)"},"name":"Wired","type":"box","y":[0.0,-0.8176,-0.3182,-0.4404,0.6486]},{"marker":{"color":"rgb(12, 102, 14)"},"name":"New York Times","type":"box","y":[-0.4019,0.0258,0.0,-0.296,-0.836,0.3182,0.3182,-0.4588,-0.6124,0.3182,0.0,0.0,-0.7845,0.4215,-0.3182]},{"marker":{"color":"rgb(10, 0, 100)"},"name":"Gizmodo.com","type":"box","y":[-0.4019,0.4939,-0.7351,-0.296,0.296,-0.3818,-0.296,-0.7536,-0.4939,0.4404]},{"marker":{"color":"rgb(100, 0, 10)"},"name":"CNN","type":"box","y":[0.6908,-0.4019,0.7783,0.25,-0.296]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %% [markdown]
# <font color='red'>Insights:</font> The box plot above shows five number summary for the top news publishers. The five number summary, which includes the minimumm, Q1 (the first quartile, or the 25% mark), the median, Q3 (the third quartile, or the 75% mark), and the maximum gives us the detailed idea about the exact nature of news these sources publish.sometimes mean can be misleading as it is prone to extreame values or outliers and in such cases median gives us a better idea.
# Looking at the graph we can see that the all the publishers report news on both sides of the spectrum. i.e. positive and negative. The median for Al jazeera and BBC is significantly low which confirms without any doubt that these publishers tend to have negative outlook to their stories.
# The highly reputed, Washington Post stands by its high standards and has the median news polarity of exact 0. So does The Economist. Both of these news publishers also have highest interquartile range which goes on to show they cover both sides of the stories and are not biased.

# %%
y0 = headlines_polarity.loc[headlines_polarity['source'] == 'The Verge']['word_count']
y1 = headlines_polarity.loc[headlines_polarity['source'] == 'BBC News']['word_count']
y2 = headlines_polarity.loc[headlines_polarity['source'] == 'Wired']['word_count']
y3 = headlines_polarity.loc[headlines_polarity['source'] == 'New York Times']['word_count']
y4 = headlines_polarity.loc[headlines_polarity['source'] == 'Gizmodo.com']['word_count']
y5 = headlines_polarity.loc[headlines_polarity['source'] == 'CNN']['word_count']

trace0 = go.Box(
    y=y0,
    name = 'The Verge',
    marker = dict(
        color = 'rgb(214, 12, 140)',
    )
)
trace1 = go.Box(
    y=y1,
    name = 'BBC',
    marker = dict(
        color = 'rgb(0, 150, 128)',
    )
)
trace2 = go.Box(
    y=y2,
    name = 'Wired',
    marker = dict(
        color = 'rgb(10, 140, 208)',
    )
)
trace3 = go.Box(
    y=y3,
    name = 'New York Times',
    marker = dict(
        color = 'rgb(12, 102, 14)',
    )
)
trace4 = go.Box(
    y=y4,
    name = 'Gizmodo.com',
    marker = dict(
        color = 'rgb(10, 0, 100)',
    )
)
trace5 = go.Box(
    y=y5,
    name = 'CNN',
    marker = dict(
        color = 'rgb(100, 0, 10)',
    )
)
data = [trace0, trace1, trace2, trace3, trace4, trace5]
layout = go.Layout(
    title = "Headline Length Boxplot of Popular News publishers"
)

fig = go.Figure(data=data,layout=layout)
iplot(fig, filename = "Headline Length Boxplot of Popular News publishers")
# Out:
# <div>                            <div id="6adeecb6-ca73-4842-ae00-42314b7fbb9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6adeecb6-ca73-4842-ae00-42314b7fbb9c")) {                    Plotly.newPlot(                        "6adeecb6-ca73-4842-ae00-42314b7fbb9c",                        [{"marker":{"color":"rgb(214, 12, 140)"},"name":"The Verge","type":"box","y":[23,24,23,26,30,29,26,19,27,26,23,21]},{"marker":{"color":"rgb(0, 150, 128)"},"name":"BBC","type":"box","y":[28,26,20,22,25,27,31,24,28,24,19,24]},{"marker":{"color":"rgb(10, 140, 208)"},"name":"Wired","type":"box","y":[24,19,27,24,23]},{"marker":{"color":"rgb(12, 102, 14)"},"name":"New York Times","type":"box","y":[23,25,21,25,21,23,30,30,22,24,23,26,22,23,23]},{"marker":{"color":"rgb(10, 0, 100)"},"name":"Gizmodo.com","type":"box","y":[21,23,30,27,27,26,29,24,28,26]},{"marker":{"color":"rgb(100, 0, 10)"},"name":"CNN","type":"box","y":[23,25,26,24,29]}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth" ...

# %% [markdown]
#  <font color='red'>Insights:</font> The word count in the headline is often neglected but it is a critical aspect when  it comes to engaging with the viewers. According to a research it was discovered that the sweet spot for headlines is 18–30 words. Anything above and below that saw reduced click-through rates. We see that most of the news sources seem follow the similar trend. The Economist is quite consistent with its headline length and has no outliers or extreame values. BBC on has the least variance in the headline length.

# %%
from nltk.tokenize import word_tokenize, RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')
stop_words = stopwords.words('english')
print(type(stop_words))
specific_words_list = ['char', 'u', 'hindustan', 'doj', 'washington'] 
#stop_words.extend(specific_words_list )
def process_text(headlines):
    tokens = []
    for line in headlines:
        line = line.lower()
        toks = tokenizer.tokenize(line)
        toks = [t for t in toks if t not in stop_words]
        tokens.extend(toks)  
    return tokens
# Out:
# <class 'list'>

# %% [markdown]
# ##### word Frequency Distribution and Zipf's law
#
# Zipf law: Zipf's law states that given a large sample of words used, the frequency of any word is inversely proportional to its rank in the frequency table. So word number n has a frequency proportional to 1/n.
# Thus the most frequent word will occur about twice as often as the second most frequent word, three times as often as the third most frequent word, etc.
# For example, in one sample of words in the English language, the most frequently occurring word, 'the', accounts for nearly 7% of all the words (69,971 out of slightly over 1 million). True to Zipf's Law, the second-place word 'of' accounts for slightly over 3.5% of words (36,411 occurrences). (source: wikipedia)

# %% [markdown]
# So essentially what the law actually states is that:
# 1. The most appearing word in a corpus suppose has frequency f
# 2. The second most appearing word would have frequency roughly f/2
# 3. Then the third most appearing word would have frequency roughly f/3
# 4. Then the fourth most appearing word would have frequency roughly f/4
# and so on.
#
# What is astonishing is that this law holds true for almost all large natural language corpuses.For eg : Books, ancient scripts, even temperature trends over past years etc.
#
# I decided upon coming across Zipf’s Law that I will investigate if the mysterious Zipf's law holds true for a news corpus collected from not one but as many as 39 differnt sources of news article.

# %%
# Positive headlines and its distribution 
pos_lines = list(headlines_polarity[headlines_polarity.label == 1].headline)
# extract the headlines that had label =1 which meant it had a positive overall sentiment
pos_tokens =process_text(pos_lines)
pos_freq = nltk.FreqDist(pos_tokens)

# Now negative headlines
neg_lines = list(headlines_polarity[headlines_polarity.label == -1].headline)
# extract the headlines that had label-1 which meant it had a negative overall sentiment
neg_tokens = process_text(neg_lines)
neg_freq = nltk.FreqDist(neg_tokens)

# %% [markdown]
# Plotting the word distribution for positive sentiment words seperately and negative sentiment words seperately so that we can verify the law twice on the same corpus.

# %%
# plotting the word distribution for positive headlines
y_val = [x[1] for x in pos_freq.most_common()]
fig = plt.figure(figsize=(10,5))
plt.plot(y_val)
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Positive)")
plt.show()
# Out:
# Text(0.5, 0, 'Words')
# Text(0, 0.5, 'Frequency')
# Text(0.5, 1.0, 'Word Frequency Distribution (Positive)')

# %%
# Plotting the word frequency distribution for negative headlines
y_val = [x[1] for x in neg_freq.most_common()]
fig = plt.figure(figsize=(10,5))
plt.plot(y_val)

plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Word Frequency Distribution (Negative)")
plt.show()
# Out:
# Text(0.5, 0, 'Words')
# Text(0, 0.5, 'Frequency')
# Text(0.5, 1.0, 'Word Frequency Distribution (Negative)')

# %% [markdown]
# <font color='red'>Insights:</font> It can be seen from the above two plots that the both the Positive sentiment words as well as the negative sentiment words follow the zipf's law. Now the how do we know whether it follws the zipfs's law?
# By observing the plot we see words close to zer have a very high word frequency and then it drops to an 'L' shaped curve. which is typical characteristic of a zipfian distribution. Furthermore, It can also be inferred that Zipf’s law follows the Pareto distribution where only first 20 % of words results into 80 % of frequency of entire corpus.
# It is important to mention that In all the results, there are some instances where the word frequency not always falls to 1/2 to its previous, which is fine because overall pattern approximates the nature.

# %% [markdown]
# #### Wordcloud : To see whats dominating the news articles

# %%
data=news_articles_df
stop = ["https", "co", "char","chars"] + list(stop_words)
wc = WordCloud(stopwords=stop, max_words=700, margin=10, background_color='black',
scale=3, relative_scaling = 0.4, width=500, height=400,
random_state=1).generate(' '.join(data['combined_text']))
plt.figure(figsize=(15,15))
plt.imshow(wc, interpolation="bilinear")
plt.axis("off")
plt.show()
# Out:
# (-0.5, 1499.5, 1199.5, -0.5)

# %% [markdown]
# <font color='red'>Insights:</font> The word cloud is a analysis technique wherein more commonly the term appears within the text being analysed, the larger the word appears in the image generated. The Word cloud image above shows which words dominated the content of the news during the period of feb 14 to march 29. It is no surprise here that the term Coronavirus appears the largest in the word cloud, highlighting the global scale of the this pandemic. some of the other words that appear frequently in the news is government which I believe is again related to Covid-19 and government's response to it. some of the other interesting observation here is the term first and new. it is not quite clear in what context these were used and we will perform bigram analysis to better understand the context of these words.
# US and India also appear to have appeaared significantly in the news, this is because of President Trump's India visit in february this year. Moreover most of the News agencies are based in the US and as a result of which the they cover a lot of stories involving the United States.

# %% [markdown]
# ####  Analyzing the distribution of words and Biagram Analysis

# %%
# news article specific stopwords were downloaded from:  https://github.com/vikasing/news-stopwords.git
# Then, I removed all the news specific stopwords  from my dataframe's column of token 
def remove_stopwords(params):
    with open('data/sw.csv','r') as my_stopwords:
        stopwords_list = my_stopwords.read()
        new_list = []
        for param in params:
            if str(param) not in stopwords_list:
                new_list.append(param)
            else:
                pass # You can write something to do if the stopword is found
    my_stopwords.close()
    return (new_list)
new_list = remove_stopwords(news_articles_df['tokens'])

# %%
# A genralized function to fetch the top n words from the corpus 
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(news_articles_df['combined_text'], 20)

df1 = pd.DataFrame(common_words, columns = ['Text' , 'count'])

df1.groupby('Text').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words in the News article before removing stop words')
# Out:
# <div>                            <div id="9e6b74bc-b5f9-4a06-8ef1-5dcc6e64072c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("9e6b74bc-b5f9-4a06-8ef1-5dcc6e64072c")) {                    Plotly.newPlot(                        "9e6b74bc-b5f9-4a06-8ef1-5dcc6e64072c",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["the","chars","is","to","facebook","of","and","in","by","for","on","its","with","it","that","has","as","are","be","after"],"y":[148,88,86,85,81,73,63,61,40,37,36,31,30,30,24,22,19,19,19,17]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorb ...

# %% [markdown]
# <font color='red'>Insights:</font> We can see that before removing the stop word, the top 20 most frequently occuring words in the corpus are the, to, of, in, etc which does not make much sense these are the words that do not convey any anything about the topic. Other thing to notice here is that again even here we do see the distribution following the zipf's law.

# %%
common_words = get_top_n_words(new_list, 20)
df2 = pd.DataFrame(common_words, columns = ['Text' , 'count'])
df2.groupby('Text').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 words in News articles after removing stop words')
# Out:
# <div>                            <div id="4848e12d-868e-4596-9485-43f2ad3ade25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("4848e12d-868e-4596-9485-43f2ad3ade25")) {                    Plotly.newPlot(                        "4848e12d-868e-4596-9485-43f2ad3ade25",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["chars","facebook","image","users","outage","company","instagram","new","business","reuters","oct","verge","et","whatsapp","illustration","like","go","one","source","alex"],"y":[88,81,17,16,15,15,13,12,11,11,11,11,11,10,10,10,9,9,9,9]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"sca ...

# %% [markdown]
# <font color='red'>Insights:</font> After removing the stopwords we see that after removing the news specific stopwords, now most of the words make a lot momre sense, even though there are still some stop words present like chars, one, two which do not make much sense but overall we that the stop word removal does a good job to give us an indication as to what dominated the news. Coronavirus as expected, occured 2778 times in the arounf 4000 news articles. other frequent words compliment the wordclound plot described earlier.

# %% [markdown]
# ##### Bigram  Analysis
# Some English words occur together more frequently. For example - blue sky, do or die, best performance, heavy rain etc. So, in a text document. lets analyze which two words appeared most frequently in the news article corpus.

# %%
# A genralized function to extact the top n most frequently occuring bigram from the text corpus 
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(new_list, 20)
for word, freq in common_words:
    print(word, freq)
df4 = pd.DataFrame(common_words, columns = ['Text' , 'count'])
df4.groupby('Text').sum()['count'].sort_values(ascending=False).iplot(
    kind='bar', yTitle='Count', linecolor='black', title='Top 20 bigrams in News Corpus after removing stop words')
# Out:
# oct et 8
# image source 8
# illustration alex 7
# alex castro 7
# castro verge 7
# facebook instagram 6
# getty images 6
# image caption 6
# instagram whatsapp 5
# facebook whistleblower 5
# source getty 5
# social network 4
# et oct 4
# images image 4
# subsea cable 3
# facebook outage 3
# wall street 3
# street journal 3
# senate hearing 3
# new users 3
# <div>                            <div id="3e519e0e-a0c0-4eb9-b21c-4000dff3c43a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("3e519e0e-a0c0-4eb9-b21c-4000dff3c43a")) {                    Plotly.newPlot(                        "3e519e0e-a0c0-4eb9-b21c-4000dff3c43a",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"count","orientation":"v","text":"","type":"bar","x":["image source","oct et","castro verge","illustration alex","alex castro","image caption","getty images","facebook instagram","instagram whatsapp","source getty","facebook whistleblower","social network","images image","et oct","senate hearing","new users","subsea cable","facebook outage","street journal","wall street"],"y":[8,8,7,7,7,6,6,6,5,5,5,4,4,4,3,3,3,3,3,3]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatte ...

# %% [markdown]
# <font color='red'>Insights:</font> We can see that by looking at bigrams instead of just single words we are able to get a better sense of the what is trending in the news. We can see that the word new york bigram makes sense now as compared to earlier. Those two words individually do not make any sense but now looking at bigram we can notice that it is acttually referring to the New York City and it is probably in the news after it has now emerged as the new Coronavirus hotspot with close to 1000 deaths. We can also see the word social distancing which signifies the emphasis being given by the media on it.

# %%
# extracting the parts of specch from the news headlines using textBlob
nltk.download('averaged_perceptron_tagger')
blob = TextBlob(str(news_articles_df['title']))
pos_df = pd.DataFrame(blob.tags, columns = ['word' , 'pos'])
pos_df = pos_df.pos.value_counts()[:5]
pos_df.iplot(
    kind='bar',
    xTitle='POS',
    yTitle='count', 
    title='Top 20 Part-of-speech tagging for News Headlines')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True
# <div>                            <div id="a6f989ce-756e-4d40-b198-2190834f1775" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("a6f989ce-756e-4d40-b198-2190834f1775")) {                    Plotly.newPlot(                        "a6f989ce-756e-4d40-b198-2190834f1775",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"pos","orientation":"v","text":"","type":"bar","x":["NNP","NN","CD","IN","VBZ"],"y":[133,75,72,44,32]}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter ...

# %% [markdown]
# 1. NNP: Proper noun
# 2. CD : Cardinal digit
# 3. NN : Noun
# 4. IN : Preposition/subordinating conjunction
# 5. VB : Verb
#
# <font color='red'>Insights:</font> We can see that the parts of speech used in the News article's heaadlines are dominated by the aforementioned parts of speech. We see proper nouns appearing a lot because news articles often talk about people and or place therfore it's not surprising to see proper noun at the first place. Cardinal digit was the second most appearing POS. The reason is that the Headlines are specific and give us the quantity for example: "900 People die In Italy in one single day". Including numbers in the headlines make them specific and increase its impact on the reader. Furthermore, Headlines are complete sentences and hence the presence of preposition and conjuctions. Lastly, the Headlines are full of action verbs since they have maximum imapct on the user.

# %% [markdown]
# #### SECTION 2- Analyzing the share market

# %% [markdown]
# As News articles provides large volumes of real-time news and update, investors can potentially exploit that information by leveraging machine learning and natural language processing techniques. So do the sentiment associated with the financial news explain the volatile nature of stock market? Does the negative sentiments of the news articles for that perticular day have an impact on the closing rates of the stocks for that day?
# The following section attempts to analyze if there exists a correlation between the news sentiment and the closing price.

# %% [markdown]
# The stock market Data for this Analysis was fetched from Word trading data and the details can be found here:
# https://www.worldtradingdata.com/documentation#historical-market-data

# %%
#pip install worldtradingdata==0.1.1

# %%
#pip install worldtradingdata==0.1.1
from WorldTradingData import WorldTradingData
my_api_token = '22d8bf380ca2d8286c7f77c1ea3f4c16'
# provide the api_token once when creating the WorldTradingData instance.
# you do not need to provide the api_token on each request
wtd = WorldTradingData(my_api_token)
wtd.stock_search('AAPL') # will find all your favourite fruity stocks
# Out:
# {'0': '#################################################################################################################################',
#  '1': '#',
#  '2': '# IMPORTANT - PLEASE UPDATE YOUR API ENDPOINT',
#  '3': '#',
#  '4': '#',
#  '5': '# This API endpoint is deprecated and now has been shut down. ',
#  '6': '# To keep using our free stock market API, please update your integration to use the new marketstack API endpoint.#',
#  '7': '# You will find more information by visiting https://marketstack.com.',
#  '8': '#',
#  '9': '#################################################################################################################################'}

# %%
# Inorder to save time and effort I have used a python SDK which is available here: https://pypi.org/project/worldtradingdata/

#wt.ApiConfig.api_key = '22d8bf380ca2d8286c7f77c1ea3f4c16'

# %% [markdown]
# Getting the stock market data from 1st March to 30 March 2020

# %%
pip install requests pprint
# Out:
# Requirement already satisfied: requests in c:\users\asus\appdata\roaming\python\python37\site-packages (2.24.0)
# Collecting pprint
# Note: you may need to restart the kernel to use updated packages.
#   ERROR: Could not find a version that satisfies the requirement pprint (from versions: none)
# ERROR: No matching distribution found for pprint

# %%
import requests
from pprint import PrettyPrinter
pp = PrettyPrinter()
api_token = '22d8bf380ca2d8286c7f77c1ea3f4c16'
#Fetch Stock Data
url = 'https://api.worldtradingdata.com/api/v1/eod/'
params = {
    'symbol':'AAPL',
    'api_token':api_token,
}
response = requests.request('GET',url,params=params)
pp.pprint(response.json())
# Out:
# {'0': '#################################################################################################################################',
#  '1': '#',
#  '2': '# IMPORTANT - PLEASE UPDATE YOUR API ENDPOINT',
#  '3': '#',
#  '4': '#',
#  '5': '# This API endpoint is deprecated and now has been shut down. ',
#  '6': '# To keep using our free stock market API, please update your '
#       'integration to use the new marketstack API endpoint.#',
#  '7': '# You will find more information by visiting https://marketstack.com.',
#  '8': '#',
#  '9': '#################################################################################################################################'}

# %%
import requests
api_response=requests.get("http://api.marketstack.com/v1/eod?access_key=9147bf114caa749cd6281aa687529e4c&symbols=GS")
print(api_response.status_code)
print(api_response.json())
# Out:
# 200
# {'pagination': {'limit': 100, 'offset': 0, 'count': 100, 'total': 253}, 'data': [{'open': 378.1, 'high': 388.22, 'low': 375.5, 'close': 385.81, 'volume': 2493437.0, 'adj_high': None, 'adj_low': None, 'adj_close': 385.81, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-10-05T00:00:00+0000'}, {'open': 380.21, 'high': 386.87, 'low': 372.84, 'close': 374.15, 'volume': 2843285.0, 'adj_high': None, 'adj_low': None, 'adj_close': 374.15, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-10-04T00:00:00+0000'}, {'open': 379.44, 'high': 382.72, 'low': 375.85, 'close': 380.0, 'volume': 2381900.0, 'adj_high': None, 'adj_low': None, 'adj_close': 380.0, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-10-01T00:00:00+0000'}, {'open': 388.0, 'high': 388.02, 'low': 376.62, 'close': 378.03, 'volume': 2666974.0, 'adj_high': None, 'adj_low': None, 'adj_close': 378.03, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-30T00:00:00+0000'}, {'open': 390.68, 'high': 392.37, 'low': 384.3, 'close': 384.89, 'volume': 1952056.0, 'adj_high': None, 'adj_low': None, 'adj_close': 384.89, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-29T00:00:00+0000'}, {'open': 400.45, 'high': 404.2, 'low': 388.51, 'close': 389.5, 'volume': 2583269.0, 'adj_high': None, 'adj_low': None, 'adj_close': 389.5, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-28T00:00:00+0000'}, {'open': 396.58, 'high': 401.0, 'low': 395.2964, 'close': 399.81, 'volume': 2584940.0, 'adj_high': None, 'adj_low': None, 'adj_close': 399.81, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-27T00:00:00+0000'}, {'open': 390.47, 'high': 392.49, 'low': 388.6, 'close': 390.85, 'volume': 1788900.0, 'adj_high': None, 'adj_low': None, 'adj_close': 390.85, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-24T00:00:00+0000'}, {'open': 390.39, 'high': 393.7, 'low': 388.39, 'close': 391.86, 'volume': 2494273.0, 'adj_high': None, 'adj_low': None, 'adj_close': 391.86, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-23T00:00:00+0000'}, {'open': 380.8, 'high': 389.29, 'low': 379.71, 'close': 385.47, 'volume': 2927835.0, 'adj_high': None, 'adj_low': None, 'adj_close': 385.47, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-22T00:00:00+0000'}, {'open': 380.85, 'high': 381.5, 'low': 374.08, 'close': 375.84, 'volume': 2372347.0, 'adj_high': None, 'adj_low': None, 'adj_close': 375.84, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-21T00:00:00+0000'}, {'open': 377.82, 'high': 380.76, 'low': 372.515, 'close': 378.13, 'volume': 3675652.0, 'adj_high': None, 'adj_low': None, 'adj_close': 378.13, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-20T00:00:00+0000'}, {'open': 396.32, 'high': 399.16, 'low': 388.83, 'close': 391.46, 'volume': 3843700.0, 'adj_high': None, 'adj_low': None, 'adj_close': 391.46, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-17T00:00:00+0000'}, {'open': 404.52, 'high': 405.98, 'low': 394.89, 'close': 396.68, 'volume': 2769072.0, 'adj_high': None, 'adj_low': None, 'adj_close': 396.68, 'adj_open': None, 'adj_volume': None, 'split_factor': 1.0, 'symbol': 'GS', 'exchange': 'XNYS', 'date': '2021-09-16T00:00:00+0000'}, {'open': 398.0, 'high': 403.5539, 'low': 396.21, 'close': 401.95, 'volume': 3190067.0, 'adj_hi ...

# %%
import requests
api_res=requests.get("http://api.marketstack.com/v1/eod?access_key=9147bf114caa749cd6281aa687529e4c&symbols=FB&date_from=2021-09-05&date_to=2021-10-04")
print(api_res.status_code)
api_response=api_res.json()


for stock_data in api_response['data']:
    print(u'Ticker %s has a day high of  %s on %s' % (
      stock_data['symbol'],
      stock_data['high'],
      stock_data['date']
    ))


import pandas as pd
#pd.read_json(api_response['data'])
stock_data=pd.DataFrame(api_response['data'])
stock_data.index.names = ['date']
stock_data.reset_index(drop=True)
# Out:
# 200
# Ticker FB has a day high of  335.94 on 2021-10-04T00:00:00+0000
# Ticker FB has a day high of  345.02 on 2021-10-01T00:00:00+0000
# Ticker FB has a day high of  342.8 on 2021-09-30T00:00:00+0000
# Ticker FB has a day high of  345.23 on 2021-09-29T00:00:00+0000
# Ticker FB has a day high of  349.59 on 2021-09-28T00:00:00+0000
# Ticker FB has a day high of  355.14 on 2021-09-27T00:00:00+0000
# Ticker FB has a day high of  354.35 on 2021-09-24T00:00:00+0000
# Ticker FB has a day high of  349.67 on 2021-09-23T00:00:00+0000
# Ticker FB has a day high of  349.84 on 2021-09-22T00:00:00+0000
# Ticker FB has a day high of  360.04 on 2021-09-21T00:00:00+0000
# Ticker FB has a day high of  361.02 on 2021-09-20T00:00:00+0000
# Ticker FB has a day high of  371.41 on 2021-09-17T00:00:00+0000
# Ticker FB has a day high of  373.56 on 2021-09-16T00:00:00+0000
# Ticker FB has a day high of  377.555 on 2021-09-15T00:00:00+0000
# Ticker FB has a day high of  378.58 on 2021-09-14T00:00:00+0000
# Ticker FB has a day high of  381.75 on 2021-09-13T00:00:00+0000
# Ticker FB has a day high of  383.79 on 2021-09-10T00:00:00+0000
# Ticker FB has a day high of  379.83 on 2021-09-09T00:00:00+0000
# Ticker FB has a day high of  380.87 on 2021-09-08T00:00:00+0000
# Ticker FB has a day high of  382.95 on 2021-09-07T00:00:00+0000
#     adj_close adj_high adj_low adj_open adj_volume   close  \
# 0      326.23     None    None     None       None  326.23
# 1      343.01     None    None     None       None  343.01
# 2      339.39     None    None     None       None  339.39
# 3      339.61     None    None     None       None  339.61
# 4      340.65     None    None     None       None  340.65
# 5      353.58     None    None     None       None  353.58
# 6      352.96     None    None     None       None  352.96
# 7      345.96     None    None     None       None  345.96
# 8      343.21     None    None     None       None  343.21
# 9      357.48     None    None     None       None  357.48
# 10     355.70     None    None     None       None  355.70
# 11     364.72     None    None     None       None  364.72
# 12     373.06     None    None     None       None  373.06
# 13     373.92     None    None     None       None  373.92
# 14     376.53     None    None     None       None  376.53
# 15     376.51     None    None     None       None  376.51
# 16     378.69     None    None     None       None  378.69
# 17     378.00     None    None     None       None  378.00
# 18     377.57     None    None     None       None  377.57
# 19     382.18     None    None     None       None  382.18
#
#                         date exchange     high       low     open  \
# 0   2021-10-04T00:00:00+0000     XNAS  335.940  322.7000  335.530
# 1   2021-10-01T00:00:00+0000     XNAS  345.020  338.6400  341.610
# 2   2021-09-30T00:00:00+0000     XNAS  342.800  338.1500  340.445
# 3   2021-09-29T00:00:00+0000     XNAS  345.230  338.8800  343.150
# 4   2021-09-28T00:00:00+0000     XNAS  349.590  338.9200  347.970
# 5   2021-09-27T00:00:00+0000     XNAS  355.140  347.0800  349.805
# 6   2021-09-24T00:00:00+0000     XNAS  354.350  342.3700  343.240
# 7   2021-09-23T00:00:00+0000     XNAS  349.670  343.0000  345.355
# 8   2021-09-22T00:00:00+0000     XNAS  349.840  340.6901  347.230
# 9   2021-09-21T00:00:00+0000     XNAS  360.040  355.2900  358.500
# 10  2021-09-20T00:00:00+0000     XNAS  361.020  349.8000  359.300
# 11  2021-09-17T00:00:00+0000     XNAS  371.410  361.5900  371.410
# 12  2021-09-16T00:00:00+0000     XNAS  373.560  369.7100  372.790
# 13  2021-09-15T00:00:00+0000     XNAS  377.555  367.6700  377.400
# 14  2021-09-14T00:00:00+0000     XNAS  378.580  375.1100  377.400
# 15  2021-09-13T00:00:00+0000     XNAS  381.750  374.3451  381.680
# 16  2021-09-10T00:00:00+0000     XNAS  383.790  378.2600  381.360
# 17  2021-09-09T00:00:00+0000     XNAS  379.830  376.5650  377.640
# 18  2021-09-08T00:00:00+0000     XNAS  380.870  374.7900  380.160
# 19  2021-09-07T00:00:00+0000     XNAS  382.950  373.1500  375.880
#
#     split_factor symbol      volume
# 0            1.0     FB  42884975.0
# 1            1.0     FB  14897500.0
# 2            1.0     FB  16335481.0
# 3            1.0     FB  14004478.0
# 4            1.0     FB  20715170.0
# 5            1.0     FB  15205843.0
# 6            1.0     FB  18783900.0
# 7            1.0     FB  21665003.0
# 8            1.0     FB  43692859.0
# 9            1.0     FB  11751917.0
# 10           1.0     FB  19822772.0
# 11           1.0     FB  26274000.0
# 12           1.0     FB  11934217.0
# 13           1.0     FB  17823271.0
# 14           1.0     FB   8711569.0
# 15           1.0     FB  13026275.0
# 16           1.0     FB  11537600.0
# 17           1.0     FB   8790196.0
# 18           1.0     FB  10981047.0
# 19           1.0     FB  10798920.0

# %%
# Gs is stock market listing for goldmann Sachs
stock_data = wtd.get('GS', date_from='2021-09-19', date_to='2021-10-19')
stock_data.index.names = ['date']
stock_data=stock_data.reset_index()
stock_data.to_csv('data/Goldman_sachs1.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-2a055db8d1f5> in <module>
#       1 # Gs is stock market listing for goldmann Sachs
# ----> 2 stock_data = wtd.get('GS', date_from='2021-09-20', date_to='2021-10-19')
#       3 stock_data.index.names = ['date']
#       4 stock_data=stock_data.reset_index()
#       5 stock_data.to_csv('data/Goldman_sachs1.csv', index = False)
#
# AttributeError: 'WorldTradingData' object has no attribute 'get'

# %% [markdown]
# Collecting News Articles related to the JP morgan and share market in general

# %%
# collecting all the news Articles from the same period as the stock market prices
api_key = '1ecc9cc21d244ad88fc2d4005db841a0'
url = 'https://newsapi.org/v2/everything?'
responses = list() 
parameters_headlines = {
    'q': 'Facebook is down',
    'domains': 'marketwatch.com',
    'sortBy':'popularity',
    'pageSize': 100,
    'apiKey': api_key,
    'language': 'en',
    'from' : '2021-09-19'    
    }
rr = requests.get(url, params = parameters_headlines)
data = rr.json()
print(data)
responses = data["articles"]
stock_articles=pd.DataFrame(get_articles(responses))
stock_articles.head()
# Out:
# {'status': 'ok', 'totalResults': 33, 'articles': [{'source': {'id': None, 'name': 'MarketWatch'}, 'author': 'Jon Swartz', 'title': ': Location, location, location: Ohio is benefiting in tech growth as a major transportation hub', 'description': 'Amazon.com Inc., Google parent Alphabet Inc., and Facebook are making billion-dollar investments in and around Cincinnati and central Ohio to take advantage of airport, data centers, and a business-friendly environment with plenty of tax incentives and minima…', 'url': 'https://www.marketwatch.com/story/location-location-location-ohio-is-benefiting-in-tech-growth-as-a-major-transportation-hub-11633187887', 'urlToImage': 'https://images.mktw.net/im-402427/social', 'publishedAt': '2021-10-02T15:18:00Z', 'content': 'Hebron, Ky., is a peculiar spot as ground zero for the technology sectors latest push in Americas heartland, but Amazon Air, the e-commerce giants 5-year-old cargo airline, is operating a 800,000-squ… [+8763 chars]'}, {'source': {'id': None, 'name': 'MarketWatch'}, 'author': 'Weston Blasi', 'title': ': Facebook: Wall Street Journal report allegations are ‘mischaracterizations’', 'description': 'In a series of stories called ‘The Facebook Files,’ The Wall Street Journal detailed occurrences when the company admitted to its negative impact on teens, exempted high-profile users from some of its rules, and made changes to its algorithm that made the pla…', 'url': 'https://www.marketwatch.com/story/facebook-wall-street-journal-report-allegations-are-mischaracterizations-11632240571', 'urlToImage': 'https://images.mktw.net/im-344091/social', 'publishedAt': '2021-09-21T16:09:00Z', 'content': 'Over the last few weeks, The Wall Street Journal published a series of reporting on Facebook \r\n FB,\r\n +0.86%\r\ncalled The Facebook Files. The report detailed occurrences when the social media giant ad… [+2317 chars]'}, {'source': {'id': None, 'name': 'MarketWatch'}, 'author': 'Jon Swartz', 'title': ': Facebook grilled in Senate hearing on protecting kids online', 'description': '"Facebook has weaponized childhood vulnerabilities" in its ruthless pursuit of profits --- despite knowing the deep harm it causes, Sen. Richard Blumenthal (D., Conn.) said in an opening statement. "Facebook has evaded, misled and deceived."', 'url': 'https://www.marketwatch.com/story/facebook-grilled-in-senate-hearing-on-protecting-kids-online-11633015770', 'urlToImage': 'https://images.mktw.net/im-406292/social', 'publishedAt': '2021-09-30T15:29:00Z', 'content': 'Facebook Inc. is staring down the barrel of some of its most vocal critics in the Senate Thursday over Instagrams effects on teens.Sens. Richard Blumenthal, (D., Conn.) chairman, and Marsha Blackburn… [+4294 chars]'}, {'source': {'id': None, 'name': 'MarketWatch'}, 'author': 'Danielle Hyams', 'title': 'The Escape Home: Here’s what Airbnb CEO Brian Chesky has to say about the future of travel', 'description': 'Airbnb CEO Brian Chesky sat down with Rafat Ali, founder of Skift, at the travel news company’s annual Skift Forum last week, a global conference focused on the business of travel.', 'url': 'https://www.marketwatch.com/story/heres-what-airbnb-ceo-brian-chesky-has-to-say-about-the-future-of-travel-11633368414', 'urlToImage': 'https://images.mktw.net/im-411130/social', 'publishedAt': '2021-10-04T17:26:00Z', 'content': 'This article is reprinted by permission from The Escape Home, a newsletter for second homeowners and those who want to be. Subscribe here. © 2021. All rights reserved.\xa0Airbnb \r\n ABNB,\r\n -4.02%\r\nCEO B… [+4429 chars]'}, {'source': {'id': None, 'name': 'MarketWatch'}, 'author': 'Jon Swartz', 'title': ': New bills aim at Apple, Google and Facebook as U.S. attempts to catch up to Europe’s Big Tech push', 'description': 'U.S. lawmakers introduced another wave of proposed legislation aimed at Big Tech on Thursday, their latest attempt to catch up to what European regulators have been doing for years.', 'url': 'https://www.marketwatch.c ...
#            author                                            content  \
# 0      Jon Swartz  Hebron, Ky., is a peculiar spot as ground zero...
# 1    Weston Blasi  Over the last few weeks, The Wall Street Journ...
# 2      Jon Swartz  Facebook Inc. is staring down the barrel of so...
# 3  Danielle Hyams  This article is reprinted by permission from T...
# 4      Jon Swartz  U.S. lawmakers introduced another wave of prop...
#
#                                          description  \
# 0  Amazon.com Inc., Google parent Alphabet Inc., ...
# 1  In a series of stories called ‘The Facebook Fi...
# 2  "Facebook has weaponized childhood vulnerabili...
# 3  Airbnb CEO Brian Chesky sat down with Rafat Al...
# 4  U.S. lawmakers introduced another wave of prop...
#
#                                   photo_url              pub_date  \
# 0  https://images.mktw.net/im-402427/social  2021-10-02T15:18:00Z
# 1  https://images.mktw.net/im-344091/social  2021-09-21T16:09:00Z
# 2  https://images.mktw.net/im-406292/social  2021-09-30T15:29:00Z
# 3  https://images.mktw.net/im-411130/social  2021-10-04T17:26:00Z
# 4  https://images.mktw.net/im-336174/social  2021-10-14T18:56:00Z
#
#                                 source  \
# 0  {'id': None, 'name': 'MarketWatch'}
# 1  {'id': None, 'name': 'MarketWatch'}
# 2  {'id': None, 'name': 'MarketWatch'}
# 3  {'id': None, 'name': 'MarketWatch'}
# 4  {'id': None, 'name': 'MarketWatch'}
#
#                                                title  \
# 0  : Location, location, location: Ohio is benefi...
# 1  : Facebook: Wall Street Journal report allegat...
# 2  : Facebook grilled in Senate hearing on protec...
# 3  The Escape Home: Here’s what Airbnb CEO Brian ...
# 4  : New bills aim at Apple, Google and Facebook ...
#
#                                                  url
# 0  https://www.marketwatch.com/story/location-loc...
# 1  https://www.marketwatch.com/story/facebook-wal...
# 2  https://www.marketwatch.com/story/facebook-gri...
# 3  https://www.marketwatch.com/story/heres-what-a...
# 4  https://www.marketwatch.com/story/new-bills-ai...

# %% [markdown]
# Converting the date column from both the dataframes into date time format

# %%
# stock news articles
stock_articles['date'] = pd.to_datetime(stock_articles['pub_date']).apply(lambda x: x.date())
# stock market data 
stock_data['date'] = pd.to_datetime(stock_data['date']).apply(lambda x: x.date())

# %%
stock_articles.head()
# Out:
#            author                                            content  \
# 0      Jon Swartz  Hebron, Ky., is a peculiar spot as ground zero...
# 1    Weston Blasi  Over the last few weeks, The Wall Street Journ...
# 2      Jon Swartz  Facebook Inc. is staring down the barrel of so...
# 3  Danielle Hyams  This article is reprinted by permission from T...
# 4      Jon Swartz  U.S. lawmakers introduced another wave of prop...
#
#                                          description  \
# 0  Amazon.com Inc., Google parent Alphabet Inc., ...
# 1  In a series of stories called ‘The Facebook Fi...
# 2  "Facebook has weaponized childhood vulnerabili...
# 3  Airbnb CEO Brian Chesky sat down with Rafat Al...
# 4  U.S. lawmakers introduced another wave of prop...
#
#                                   photo_url              pub_date  \
# 0  https://images.mktw.net/im-402427/social  2021-10-02T15:18:00Z
# 1  https://images.mktw.net/im-344091/social  2021-09-21T16:09:00Z
# 2  https://images.mktw.net/im-406292/social  2021-09-30T15:29:00Z
# 3  https://images.mktw.net/im-411130/social  2021-10-04T17:26:00Z
# 4  https://images.mktw.net/im-336174/social  2021-10-14T18:56:00Z
#
#                                 source  \
# 0  {'id': None, 'name': 'MarketWatch'}
# 1  {'id': None, 'name': 'MarketWatch'}
# 2  {'id': None, 'name': 'MarketWatch'}
# 3  {'id': None, 'name': 'MarketWatch'}
# 4  {'id': None, 'name': 'MarketWatch'}
#
#                                                title  \
# 0  : Location, location, location: Ohio is benefi...
# 1  : Facebook: Wall Street Journal report allegat...
# 2  : Facebook grilled in Senate hearing on protec...
# 3  The Escape Home: Here’s what Airbnb CEO Brian ...
# 4  : New bills aim at Apple, Google and Facebook ...
#
#                                                  url        date
# 0  https://www.marketwatch.com/story/location-loc...  2021-10-02
# 1  https://www.marketwatch.com/story/facebook-wal...  2021-09-21
# 2  https://www.marketwatch.com/story/facebook-gri...  2021-09-30
# 3  https://www.marketwatch.com/story/heres-what-a...  2021-10-04
# 4  https://www.marketwatch.com/story/new-bills-ai...  2021-10-14

# %%
stock_data = stock_data.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')
#stock_data = stock_data.rename(index = {'date': 'date1'})

# %% [markdown]
# I wanted both the dataframes merged into one so that it is easy for plotting therfore I merged the two data frame on date column

# %%
stock_data.head()
# Out:
#    adj_close adj_high adj_low adj_open adj_volume   close        date  \
# 0     326.23     None    None     None       None  326.23  2021-10-04
# 1     343.01     None    None     None       None  343.01  2021-10-01
# 2     339.39     None    None     None       None  339.39  2021-09-30
# 3     339.61     None    None     None       None  339.61  2021-09-29
# 4     340.65     None    None     None       None  340.65  2021-09-28
#
#   exchange    high     low     open  split_factor symbol      volume
# 0     XNAS  335.94  322.70  335.530           1.0     FB  42884975.0
# 1     XNAS  345.02  338.64  341.610           1.0     FB  14897500.0
# 2     XNAS  342.80  338.15  340.445           1.0     FB  16335481.0
# 3     XNAS  345.23  338.88  343.150           1.0     FB  14004478.0
# 4     XNAS  349.59  338.92  347.970           1.0     FB  20715170.0

# %%
df_merged=stock_data.merge(stock_articles,on='date')
df_merged.head()
# Out:
#    adj_close adj_high adj_low adj_open adj_volume   close        date  \
# 0     326.23     None    None     None       None  326.23  2021-10-04
# 1     326.23     None    None     None       None  326.23  2021-10-04
# 2     326.23     None    None     None       None  326.23  2021-10-04
# 3     326.23     None    None     None       None  326.23  2021-10-04
# 4     326.23     None    None     None       None  326.23  2021-10-04
#
#   exchange    high    low    open  split_factor symbol      volume  \
# 0     XNAS  335.94  322.7  335.53           1.0     FB  42884975.0
# 1     XNAS  335.94  322.7  335.53           1.0     FB  42884975.0
# 2     XNAS  335.94  322.7  335.53           1.0     FB  42884975.0
# 3     XNAS  335.94  322.7  335.53           1.0     FB  42884975.0
# 4     XNAS  335.94  322.7  335.53           1.0     FB  42884975.0
#
#               author                                            content  \
# 0     Danielle Hyams  This article is reprinted by permission from T...
# 1    Rick Bookstaber  Diversification is the most powerful concept i...
# 2      Mark DeCambre  After a woeful September for optimists, the st...
# 3  Barbara Kollmeyer  A risk-off Monday is brewing to start the week...
# 4  Wallace Witkowski  Facebook Inc. lost money in more ways than one...
#
#                                          description  \
# 0  Airbnb CEO Brian Chesky sat down with Rafat Al...
# 1  Investors with S&P 500 index funds and ETFs ma...
# 2  After a woeful September for optimists, the st...
# 3  Now isn’t the time to let down your defenses, ...
# 4  Outage cost company about $164,000 a minute in...
#
#                                   photo_url              pub_date  \
# 0  https://images.mktw.net/im-411130/social  2021-10-04T17:26:00Z
# 1  https://images.mktw.net/im-410438/social  2021-10-04T09:03:00Z
# 2  https://images.mktw.net/im-411174/social  2021-10-04T19:38:00Z
# 3  https://images.mktw.net/im-410823/social  2021-10-04T11:23:00Z
# 4  https://images.mktw.net/im-364450/social  2021-10-04T22:38:00Z
#
#                                 source  \
# 0  {'id': None, 'name': 'MarketWatch'}
# 1  {'id': None, 'name': 'MarketWatch'}
# 2  {'id': None, 'name': 'MarketWatch'}
# 3  {'id': None, 'name': 'MarketWatch'}
# 4  {'id': None, 'name': 'MarketWatch'}
#
#                                                title  \
# 0  The Escape Home: Here’s what Airbnb CEO Brian ...
# 1  Next Avenue: Your index funds may not be as di...
# 2  In One Chart: A stock-market correction is bre...
# 3  Need to Know: Buy the dip has failed. Here’s w...
# 4  : Facebook outage, by the numbers: Largest out...
#
#                                                  url
# 0  https://www.marketwatch.com/story/heres-what-a...
# 1  https://www.marketwatch.com/story/your-index-f...
# 2  https://www.marketwatch.com/story/a-stock-mark...
# 3  https://www.marketwatch.com/story/buy-the-dip-...
# 4  https://www.marketwatch.com/story/facebook-out...

# %%
# applying all the preprocessing steps that were described in section 1
# merging the title and content and the description 
df_merged['combined_text'] = df_merged['title'].map(str) +" "+ df_merged['content']+" "+ df_merged['description'].map(str)

# %%
# keeping only the essential columns in the dataframe
df_merged=df_merged[['date','close','combined_text']]
df_merged.head()
# Out:
#          date   close                                      combined_text
# 0  2021-10-04  326.23  The Escape Home: Here’s what Airbnb CEO Brian ...
# 1  2021-10-04  326.23  Next Avenue: Your index funds may not be as di...
# 2  2021-10-04  326.23  In One Chart: A stock-market correction is bre...
# 3  2021-10-04  326.23  Need to Know: Buy the dip has failed. Here’s w...
# 4  2021-10-04  326.23  : Facebook outage, by the numbers: Largest out...

# %%
# Calculating the sentiment scores for the Sttock news articles exactly as described earlier

# %%
sia = SIA()
results = []
for line in df_merged['combined_text'] :
    pol_score = sia.polarity_scores(line)
    pol_score['headline'] = line
    results.append(pol_score)
# to avoid an error
pd.set_option('mode.chained_assignment', None)
df_merged['compound']=''
df_merged['neg']=''
df_merged['neu']=''
df_merged['pos']=''
for index,sentence in enumerate(df_merged['combined_text']):
    ps=sia.polarity_scores(sentence)
    df_merged['compound'][index]=ps['compound']
    df_merged['neg'][index]=ps['neg']
    df_merged['neu'][index]=ps['neu']
    df_merged['pos'][index]=ps['pos']

# %%
df_merged.head()
# Out:
#          date   close                                      combined_text  \
# 0  2021-10-04  326.23  The Escape Home: Here’s what Airbnb CEO Brian ...
# 1  2021-10-04  326.23  Next Avenue: Your index funds may not be as di...
# 2  2021-10-04  326.23  In One Chart: A stock-market correction is bre...
# 3  2021-10-04  326.23  Need to Know: Buy the dip has failed. Here’s w...
# 4  2021-10-04  326.23  : Facebook outage, by the numbers: Largest out...
#
#   compound    neg    neu    pos
# 0   0.6486      0  0.912  0.088
# 1   0.0498  0.084  0.842  0.073
# 2    0.296  0.058  0.842    0.1
# 3  -0.4019  0.074  0.875  0.051
# 4  -0.7485  0.083  0.917      0

# %% [markdown]
# From the above dataframe we can see that there are two or more entries for the same date. which is because there can be more than one news article being published on a day so I decided to keep the most recent news and the sentiment associated with it.

# %%
df_merged=df_merged.drop_duplicates(subset='date', keep="last")
df_merged.head()
# Out:
#           date   close                                      combined_text  \
# 7   2021-10-04  326.23  A stock-market correction is brewing in the Na...
# 9   2021-09-30  339.39  Need to Know: Facebook, Alphabet and Twitter a...
# 10  2021-09-29  339.61  Deep Dive: More than a quarter of Nasdaq-100 s...
# 11  2021-09-28  340.65  Crypto: Crypto-trading hamster Mr. Goxx is up ...
# 12  2021-09-24  352.96  Facebook safety exec to face Senate panel next...
#
#    compound    neg    neu    pos
# 7     0.296   0.06  0.837  0.103
# 9    0.5089  0.084  0.788  0.128
# 10   0.6361      0  0.934  0.066
# 11   0.5994      0  0.912  0.088
# 12  -0.6705   0.08  0.878  0.042

# %% [markdown]
# Now for the purpose of plotting both the stock market close price and the negative sentiment on the same plot and the axis, the close price of the stock market must be between 0 and 1 just like the sentiment score. Therefore I decided to normalize it using sklearn library.

# %%
# Min-Max Normalization 
from sklearn import preprocessing
# Create x, where x the 'scores' column's values as floats
x = df_merged[['close']].values.astype(float)
# Create a minimum and maximum processor object
min_max_scaler = preprocessing.MinMaxScaler()
# Create an object to transform the data to fit minmax processor
x_scaled = min_max_scaler.fit_transform(x)
# adding the new column to our dataframe
df_merged['normal_close']= x_scaled

# %%
df_merged.head()
# Out:
#           date   close                                      combined_text  \
# 7   2021-10-04  326.23  A stock-market correction is brewing in the Na...
# 9   2021-09-30  339.39  Need to Know: Facebook, Alphabet and Twitter a...
# 10  2021-09-29  339.61  Deep Dive: More than a quarter of Nasdaq-100 s...
# 11  2021-09-28  340.65  Crypto: Crypto-trading hamster Mr. Goxx is up ...
# 12  2021-09-24  352.96  Facebook safety exec to face Senate panel next...
#
#    compound    neg    neu    pos  normal_close
# 7     0.296   0.06  0.837  0.103       0.00000
# 9    0.5089  0.084  0.788  0.128       0.42112
# 10   0.6361      0  0.934  0.066       0.42816
# 11   0.5994      0  0.912  0.088       0.46144
# 12  -0.6705   0.08  0.878  0.042       0.85536

# %%
import matplotlib.pyplot as plt
import pandas as pd
# gca stands for 'get current axis'
ax = plt.gca()
df_merged.plot(kind='line',x='date',y='normal_close',ax=ax, figsize=(18,10))
ax.set_ylabel("Normalized stock close")
df_merged.plot(kind='line',x='date',y='neg', color='red',title='Variation in Stock prices and the News Sentiments', ax=ax, figsize=(18,10))
plt.show()
# Out:
# Text(0, 0.5, 'Normalized stock close')

# %% [markdown]
# Calculating Correlation Coedicents to emperically determine the relationship between the variables

# %%
from scipy.stats import pearsonr
from scipy.stats import spearmanr
# calculate the Pearsons and Spearmans correlation between two variables
# prepare data
data1 = df_merged['neg']  
data2 = df_merged['normal_close'] 
# calculate Pearson's correlation
corr, _ = pearsonr(data1, data2)
print('Pearsons correlation: %.3f' % corr)
# calculate Spearmans's correlation (non gaussian distribution)
corr, _ = spearmanr(data1, data2)
print('Spearmans correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.068
# Spearmans correlation: 0.018

# %% [markdown]
# <font color='red'>Insights:</font> Form the Data collected, and the graph drawn above there seem to be no correslation between the negative sentiment of the news and the stock's end of the daya close price. I further confirmed this by calculating the correlation coefficents, namely pearson's and Spearmann's. Both of them vary between -1 and 1 wherein -1 shows negative correlation and 1 shows positive correlation between the two entities. I calculated both of them because pearsonn's correlation is not suitable when the distribution of daa is normal in nature. So in all such cases, spearmans corelation is used but foe this analysis none of them suggested the presence of strong correlation between the two variables. I even tried changing various news sources and the company listing but none of them showed any signs of correlation. The correlation coefficents do suggest small negative correlation but that is small and insignificant.
#
# I expected the end of the day stock price to have negative correlation with negative news sentiment but then results proved otherwise. Upon some critical thinking and research I was able to figure out the reason for the same. Due to the prevailing economic conditions, the behaviour of the financial markets is negative in nature and the coronavirus pandemic has negatively afftected all the major industries. As a result of which this, the present scenario is probably the worst time to do such analysis as there are multiple factors affeting the stock prices, and moreover when the world economy is heading into the biggest recession of our lifetime, the analysis results do not capture the entire story.

# %% [markdown]
# ### Conclusion
#
# In summary, we have answered for the initial questions through the means of analysis of the news articles. We have concluded that though we may feel as if the media is focussing too much on the negative side of the story, this is certainly not the case in reality. The Positive and the negative sentiments associated with over 4000 news articles clearly  indicates that both sentiments are equally present in the news articles. Furthermore, We also found that there are some news publishers like Al Jazeera and BBC news that have a high median negative sentiment polarity.
# We were also able to figure out the Ideal length of the headleans from the trends observed. It seemed 18-30 words made up the headline in most news articles.
# All the subsequent analysis focussed on finding the major trends in the news and to analyse how the content of news articles and headlines. In the final section, We performed the sentiment analysis of the financial market news to determine if there exists any correlation between the end of the day close price and the negative news sentiment, It was found that there appears to be very small degree of negative correlation between the two.
#
# In Conclusion, I beleive this project was an attempt to perform Sentiment analysis of the News articles and see its impact on the world around us. In future, I would love to collect more  historial data for the stock prices and the news sentiments (for atleast 5-10 year period ) and then analyze the presence of any correlation between the same. Sice the primary aim of this project was not to determine the correlation between the two, I have kept things simple in the second section of this project. In future, We can also fit a machine learning model to predict the close price of stock from the news sentiment.
